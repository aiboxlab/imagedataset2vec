# %%
import os
import re
import math
import pickle
import random
import Orange
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from humanize import ordinal
from scikit_posthocs import posthoc_nemenyi
from scipy.stats import mannwhitneyu
from scipy.spatial import ConvexHull
from skcriteria import Data, MAX
from skcriteria.madm.closeness import TOPSIS
from sklearn.preprocessing import normalize
from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import KMeans
from sklearn.model_selection import LeaveOneOut
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
RESULTS_PATH = 'data/results'
TASKS_FEATURES_FILEPATH = 'data/tasks_features.pkl'

# %%
results_dfs = {}
for filename in os.listdir(RESULTS_PATH):
    archtecture = re.search(r'(?<=results_).*(?=.csv)', filename).group()
    results_dfs[archtecture] = pd.read_csv(os.path.join(RESULTS_PATH, filename))

# %%
results_df = pd.concat(results_dfs.values(), ignore_index=True)

# %%
results_df.head()
# Out:
#   Architecture                 Task  \
# 0     ResNet10  airplane-automobile
# 1     ResNet10        airplane-bird
# 2     ResNet10         airplane-cat
# 3     ResNet10        airplane-deer
# 4     ResNet10         airplane-dog
#
#                                      Accuracy_vector  \
# 0  [0.942, 0.939, 0.93, 0.9275, 0.916, 0.9315, 0....
# 1  [0.89, 0.889, 0.8935, 0.882, 0.875, 0.8895, 0....
# 2  [0.9245, 0.9325, 0.935, 0.926, 0.932, 0.925, 0...
# 3  [0.9475, 0.9125, 0.943, 0.93, 0.917, 0.936, 0....
# 4  [0.948, 0.9515, 0.936, 0.947, 0.9345, 0.9475, ...
#
#                                     Precision_vector  \
# 0  [0.9203510204081633, 0.9051657032755298, 0.893...
# 1  [0.8614113785557986, 0.8492249488752557, 0.852...
# 2  [0.8897871921182265, 0.8980344995140912, 0.905...
# 3  [0.9234072781655036, 0.8553790534618757, 0.921...
# 4  [0.924704, 0.9361238390092881, 0.9224043010752...
#
#                                        Recall_vector  \
# 0  [0.932, 0.958, 0.948, 0.939, 0.954, 0.938, 0.8...
# 1  [0.847, 0.878, 0.89, 0.886, 0.888, 0.89, 0.887...
# 2  [0.932, 0.947, 0.937, 0.938, 0.961, 0.909, 0.8...
# 3  [0.949, 0.983, 0.933, 0.98, 0.935, 0.928, 0.95...
# 4  [0.948, 0.936, 0.901, 0.95, 0.914, 0.93, 0.955...
#
#                                            F1_vector  Accuracy_avg  \
# 0  [0.9414141414141414, 0.9401373895976447, 0.931...       0.92505
# 1  [0.8850574712643677, 0.8877654196157735, 0.893...       0.88480
# 2  [0.9250620347394541, 0.933464760965993, 0.9351...       0.92580
# 3  [0.947578632051922, 0.9182624941616068, 0.9424...       0.93320
# 4  [0.948, 0.9507364144235654, 0.9336787564766839...       0.94470
#
#    Precision_avg  Recall_avg    F1_avg
# 0       0.892683      0.9274  0.925149
# 1       0.843588      0.8753  0.883662
# 2       0.893557      0.9279  0.925876
# 3       0.900529      0.9460  0.934192
# 4       0.923633      0.9363  0.944177

# %%
TASKS = results_df['Task'].unique()
ARCHITECTURES = results_df['Architecture'].unique()

# %%
label_encoder = LabelEncoder()
label_encoder.fit(ARCHITECTURES)
# Out:
# LabelEncoder()

# %%
leave_one_out = LeaveOneOut()

# %%
metrics_avg = {}
metrics_vectors = {}
for task in TASKS:
    df = results_df.query(f'Task == "{task}"')
    metrics_avg[task] = {}
    metrics_vectors[task] = {}
    for _, row in df.iterrows():
        metrics_avg[task][row['Architecture']] = {
            'accuracy': row['Accuracy_avg'],
            'precision': row['Precision_avg'],
            'recall': row['Recall_avg'],
            'f1': row['F1_avg']
        }
        metrics_vectors[task][row['Architecture']] = {
            'accuracy': np.array(eval(row['Accuracy_vector'])),
            'precision': np.array(eval(row['Precision_vector'])),
            'recall': np.array(eval(row['Recall_vector'])),
            'f1': np.array(eval(row['F1_vector']))
        }

# %%
ranking_architectures = {}
for task in TASKS:
    metrics_columns = ['Accuracy_avg', 'Precision_avg', 'Recall_avg', 'F1_avg']
    metrics_df = results_df.query(f'Task == "{task}"')[metrics_columns]
    data = Data(metrics_df.to_numpy(), criteria=[MAX, MAX, MAX, MAX])
    topsis = TOPSIS()
    ranking_architectures[task] = results_df.iloc[
        metrics_df.index[np.argsort(topsis.decide(data).rank_)]
    ]['Architecture'].tolist()

# %%
with open(TASKS_FEATURES_FILEPATH, 'rb') as f:
    tasks_features = pickle.load(f)

# %%
# %%time

mean_centroids = []
best_architectures = []
for task in TASKS:
    task_features = tasks_features[task]
    task_features_normalized = normalize(task_features, axis=0)
    kmeans = KMeans(n_clusters=2, n_jobs=3)
    kmeans.fit(task_features_normalized)
    centroids = kmeans.cluster_centers_
    mean_centroids.append(np.add(*centroids) / centroids.shape[0])
    best_architectures.append(ranking_architectures[task][0])
# Out:
# CPU times: user 2.27 s, sys: 519 ms, total: 2.79 s
# Wall time: 29.6 s

# %%
X = np.array(mean_centroids)
y = label_encoder.transform(best_architectures)

# %%
lda = LinearDiscriminantAnalysis(n_components=2)

# %%
component_x, component_y = lda.fit_transform(X, y).T

# %%
AlexNet1_index = [i for i, architecture in enumerate(best_architectures) if architecture == 'AlexNet1']
MiniGoogLeNet1_index = [i for i, architecture in enumerate(best_architectures) if architecture == 'MiniGoogLeNet1']
MiniVGG1_index = [i for i, architecture in enumerate(best_architectures) if architecture == 'MiniVGG1']
MiniVGG3_index = [i for i, architecture in enumerate(best_architectures) if architecture == 'MiniVGG3']

# %%
def encircle(x, y, ax=None, **kw):
    if not ax:
        ax = plt.gca()
    p = np.c_[x,y]
    hull = ConvexHull(p)
    poly = plt.Polygon(p[hull.vertices, :], **kw)
    ax.add_patch(poly)

# %%
g = sns.scatterplot(component_x, component_y, hue=best_architectures, style=best_architectures)
g.legend(fontsize='x-small', frameon=False)

encircle(component_x[AlexNet1_index], component_y[AlexNet1_index], ec='red', fc='red', alpha=0.15)
encircle(component_x[MiniGoogLeNet1_index], component_y[MiniGoogLeNet1_index], ec='green', fc='green', alpha=0.15)
encircle(component_x[MiniVGG1_index], component_y[MiniVGG1_index], ec='orange', fc='orange', alpha=0.15)
encircle(component_x[MiniVGG3_index], component_y[MiniVGG3_index], ec='blue', fc='blue', alpha=0.15)

plt.savefig('datasets_map.png', dpi=1200, bbox_inches='tight')
plt.show()

# %%
# %%time

knn_recommendations = {}
for train_index, test_index in leave_one_out.split(TASKS):
    clf = KNeighborsClassifier()
    clf.fit(X[train_index], y[train_index])
    task = TASKS[test_index[0]]
    recommended_architecture = label_encoder.inverse_transform(
        clf.predict(X[test_index])
    )[0]
    knn_recommendations[task] = recommended_architecture
# Out:
# CPU times: user 76.9 ms, sys: 191 µs, total: 77.1 ms
# Wall time: 77.1 ms

# %%
# %%time

svm_recommendations = {}
for train_index, test_index in leave_one_out.split(TASKS):
    clf = SVC()
    clf.fit(X[train_index], y[train_index])
    task = TASKS[test_index[0]]
    recommended_architecture = label_encoder.inverse_transform(
        clf.predict(X[test_index])
    )[0]
    svm_recommendations[task] = recommended_architecture
# Out:
# CPU times: user 55.2 ms, sys: 3.61 ms, total: 58.9 ms
# Wall time: 58 ms

# %%
# %%time

rf_recommendations = {}
for train_index, test_index in leave_one_out.split(TASKS):
    clf = RandomForestClassifier()
    clf.fit(X[train_index], y[train_index])
    task = TASKS[test_index[0]]
    recommended_architecture = label_encoder.inverse_transform(
        clf.predict(X[test_index])
    )[0]
    rf_recommendations[task] = recommended_architecture
# Out:
# CPU times: user 8.19 s, sys: 22.6 ms, total: 8.22 s
# Wall time: 8.22 s

# %%
# %%time

oner_recommendations = []
for _ in range(10):
    recommended_architecture = random.choice(ARCHITECTURES)
    oner_recommendations.append({
        task: recommended_architecture
        for task in TASKS
    })
# Out:
# CPU times: user 128 µs, sys: 10 µs, total: 138 µs
# Wall time: 133 µs

# %%
# %%time

random_recommendations = []
for _ in range(10):
    random_recommendations.append({
        task: random.choice(ARCHITECTURES)
        for task in TASKS
    })
# Out:
# CPU times: user 624 µs, sys: 0 ns, total: 624 µs
# Wall time: 633 µs

# %%
def make_results(recommendations):
    results = {}
    for task in TASKS:
        best_architecture = ranking_architectures[task][0]
        worst_architecture = ranking_architectures[task][-1]
        recommended_architecture = recommendations[task]
        results[task] = {
            'Ranking_architectures': ', '.join(ranking_architectures[task]),
            'Recommendation_rank': ordinal(ranking_architectures[task].index(recommended_architecture) + 1),
            'P_value[best]': mannwhitneyu(
                metrics_vectors[task][recommended_architecture]['accuracy'],
                metrics_vectors[task][best_architecture]['accuracy']
            )[1],
            'P_value[worst]': mannwhitneyu(
                metrics_vectors[task][recommended_architecture]['accuracy'],
                metrics_vectors[task][worst_architecture]['accuracy']
            )[1],
            'Architecture[recommended]': recommended_architecture,
            'Architecture[best]': best_architecture,
            'Architecture[worst]': worst_architecture,
            'Accuracy_avg[recommended]': metrics_avg[task][recommended_architecture]['accuracy'],
            'Accuracy_avg[best]': metrics_avg[task][best_architecture]['accuracy'],
            'Accuracy_avg[worst]': metrics_avg[task][worst_architecture]['accuracy'],
            'Precision_avg[recommended]': metrics_avg[task][recommended_architecture]['precision'],
            'Precision_avg[best]': metrics_avg[task][best_architecture]['precision'],
            'Precision_avg[worst]': metrics_avg[task][worst_architecture]['precision'],
            'Recall_avg[recommended]': metrics_avg[task][recommended_architecture]['recall'],
            'Recall_avg[best]': metrics_avg[task][best_architecture]['recall'],
            'Recall_avg[worst]': metrics_avg[task][worst_architecture]['recall'],
            'F1_avg[recommended]': metrics_avg[task][recommended_architecture]['f1'],
            'F1_avg[best]': metrics_avg[task][best_architecture]['f1'],
            'F1_avg[worst]': metrics_avg[task][worst_architecture]['f1']
        }
    return results

# %%
knn_results = make_results(knn_recommendations)
svm_results = make_results(svm_recommendations)
rf_results = make_results(rf_recommendations)

# %%
knn_results_df = pd.DataFrame(knn_results).T.rename_axis('Task').reset_index()
svm_results_df = pd.DataFrame(svm_results).T.rename_axis('Task').reset_index()
rf_results_df = pd.DataFrame(rf_results).T.rename_axis('Task').reset_index()

# %%
oner_results_10_executions = [
    make_results(recommendations)
    for recommendations in oner_recommendations
]

# %%
random_results_10_executions = [
    make_results(recommendations)
    for recommendations in random_recommendations
]

# %%
oner_results_df = pd.concat([
    pd.DataFrame(results).T.rename_axis('Task').reset_index()
    for results in oner_results_10_executions
], ignore_index=True)

# %%
random_results_df = pd.concat([
    pd.DataFrame(results).T.rename_axis('Task').reset_index()
    for results in random_results_10_executions
], ignore_index=True)

# %%
knn_results_df
# Out:
#                    Task                              Ranking_architectures  \
# 0   airplane-automobile  MiniVGG3, MiniVGG1, AlexNet1, MiniGoogLeNet1, ...
# 1         airplane-bird  MiniVGG1, MiniGoogLeNet1, MiniVGG3, AlexNet1, ...
# 2          airplane-cat  MiniVGG3, MiniVGG1, AlexNet1, ResNet10, MiniGo...
# 3         airplane-deer  MiniGoogLeNet1, MiniVGG3, AlexNet1, ResNet10, ...
# 4          airplane-dog  MiniVGG3, MiniGoogLeNet1, AlexNet1, MiniVGG1, ...
# 5         airplane-frog  MiniVGG3, AlexNet1, MiniGoogLeNet1, SmallSquee...
# 6        airplane-horse  MiniVGG3, MiniVGG1, MiniGoogLeNet1, AlexNet1, ...
# 7         airplane-ship  MiniVGG3, AlexNet1, MiniGoogLeNet1, MiniVGG1, ...
# 8        airplane-truck  MiniVGG3, AlexNet1, MiniGoogLeNet1, MiniVGG1, ...
# 9       automobile-bird  MiniGoogLeNet1, MiniVGG3, AlexNet1, MiniVGG1, ...
# 10       automobile-cat  MiniVGG3, MiniGoogLeNet1, AlexNet1, MiniVGG1, ...
# 11      automobile-deer  AlexNet1, MiniGoogLeNet1, MiniVGG3, SmallSquee...
# 12       automobile-dog  MiniGoogLeNet1, MiniVGG3, MiniVGG1, AlexNet1, ...
# 13      automobile-frog  MiniGoogLeNet1, MiniVGG3, ResNet10, AlexNet1, ...
# 14     automobile-horse  MiniVGG3, MiniGoogLeNet1, AlexNet1, MiniVGG1, ...
# 15      automobile-ship  MiniGoogLeNet1, AlexNet1, MiniVGG3, ResNet10, ...
# 16     automobile-truck  MiniVGG3, AlexNet1, MiniGoogLeNet1, MiniVGG1, ...
# 17             bird-cat  MiniGoogLeNet1, MiniVGG3, AlexNet1, MiniVGG1, ...
# 18            bird-deer  MiniVGG1, MiniVGG3, AlexNet1, MiniGoogLeNet1, ...
# 19             bird-dog  MiniVGG1, AlexNet1, MiniVGG3, MiniGoogLeNet1, ...
# 20            bird-frog  AlexNet1, MiniVGG3, MiniGoogLeNet1, MiniVGG1, ...
# 21           bird-horse  MiniVGG3, MiniVGG1, AlexNet1, MiniGoogLeNet1, ...
# 22            bird-ship  AlexNet1, MiniVGG3, MiniGoogLeNet1, MiniVGG1, ...
# 23           bird-truck  MiniGoogLeNet1, MiniVGG3, MiniVGG1, AlexNet1, ...
# 24             cat-deer  MiniVGG3, AlexNet1, MiniGoogLeNet1, MiniVGG1, ...
# 25              cat-dog  MiniVGG3, MiniGoogLeNet1, AlexNet1, MiniVGG1, ...
# 26             cat-frog  MiniVGG3, MiniGoogLeNet1, AlexNet1, MiniVGG1, ...
# 27            cat-horse  MiniVGG3, AlexNet1, MiniGoogLeNet1, MiniVGG1, ...
# 28             cat-ship  MiniVGG3, AlexNet1, MiniVGG1, ResNet10, MiniGo...
# 29            cat-truck  MiniGoogLeNet1, MiniVGG3, AlexNet1, ResNet10, ...
# 30             deer-dog  MiniVGG3, MiniGoogLeNet1, AlexNet1, ResNet10, ...
# 31            deer-frog  MiniVGG3, MiniGoogLeNet1, AlexNet1, MiniVGG1, ...
# 32           deer-horse  MiniGoogLeNet1, MiniVGG3, AlexNet1, SmallSquee...
# 33            deer-ship  MiniGoogLeNet1, MiniVGG3, AlexNet1, MiniVGG1, ...
# 34           deer-truck  MiniVGG1, MiniVGG3, AlexNet1, MiniGoogLeNet1, ...
# 35             dog-frog  MiniVGG3, AlexNet1, MiniGoogLeNet1, MiniVGG1, ...
# 36            dog-horse  MiniVGG1, MiniVGG3, MiniGoogLeNet1, AlexNet1, ...
# 37             dog-ship  MiniVGG1, MiniGoogLeNet1, MiniVGG3, AlexNet1, ...
# 38            dog-truck  MiniGoogLeNet1, MiniVGG1, MiniVGG3, ResNet10, ...
# 39           frog-horse  MiniGoogLeNet1, MiniVGG3, ResNet10, MiniVGG1, ...
# 40            frog-ship  MiniGoogLeNet1, MiniVGG3, MiniVGG1, SmallSquee...
# 41           frog-truck  MiniVGG3, ResNet10, MiniGoogLeNet1, MiniVGG1, ...
# 42           horse-ship  MiniVGG3, AlexNet1, MiniVGG1, MiniGoogLeNet1, ...
# 43          horse-truck  MiniVGG3, MiniVGG1, MiniGoogLeNet1, AlexNet1, ...
# 44           ship-truck  MiniVGG3, MiniGoogLeNet1, AlexNet1, MiniVGG1, ...
#
#    Recommendation_rank P_value[best] P_value[worst] Architecture[recommended]  \
# 0                  4th    0.00505429      0.0347163            MiniGoogLeNet1
# 1                  3rd      0.298282       0.012874                  MiniVGG3
# 2                  1st      0.484822     0.00109688                  MiniVGG3
# 3                  2nd     0.0376108      0.0141233                  MiniVGG3
# 4                  2nd      0.424914    8.78078e-05            MiniGoogLeNet1
# 5                  3rd      0.136428     0.00158141            MiniGoogLeNet1
# 6                  1st      0.484822    9.03174e-05                  MiniVGG3
# 7                  1st      0.484822    0.000122402                  MiniVGG3
# 8                  1st      0.484868     0.00505429                  MiniVGG3
# 9                  2nd      0.324704    0.000743288                  MiniVGG3
# 10                 2nd      0.285012    0.000954682            MiniGoogLeNet1
# 11                 2nd     0.0736901    8.78078e-05            MiniGoogLeNet1
# 12                 1st      0.484822    0.000250809            MiniGoogLeNet1
# 13                 2nd    0.00173035     0.00563412                  MiniVGG3
# 14                 2nd     0.0170456     0.00286102            MiniGoogLeNet1
# 15                 1st      0.484868    0.000141807            MiniGoogLeNet1
# 16                 1st      0.484868     0.00289768                  MiniVGG3
# 17                 2nd      0.410265    9.13359e-05                  MiniVGG3
# 18                 2nd      0.338678    0.000503988                  MiniVGG3
# 19                 3rd      0.285375      0.0003333                  MiniVGG3
# 20                 2nd      0.484919      0.0205869                  MiniVGG3
# 21                 4th     0.0753098     0.00862873            MiniGoogLeNet1
# 22                 4th      0.272524      0.0187817                  MiniVGG1
# 23                 2nd     0.0242566    9.03174e-05                  MiniVGG3
# 24                 1st      0.484868    0.000497378                  MiniVGG3
# 25                 1st      0.484868    8.93072e-05                  MiniVGG3
# 26                 2nd      0.454844    9.08256e-05            MiniGoogLeNet1
# 27                 1st      0.484822    9.08256e-05                  MiniVGG3
# 28                 1st      0.484822     0.00287016                  MiniVGG3
# 29                 2nd      0.144505      0.0188177                  MiniVGG3
# 30                 2nd      0.248065     0.00010551            MiniGoogLeNet1
# 31                 4th   0.000288645       0.236171                  MiniVGG1
# 32                 2nd      0.338792    9.08256e-05                  MiniVGG3
# 33                 4th   0.000379012       0.484919                  MiniVGG1
# 34                 4th     0.0918599      0.0104943            MiniGoogLeNet1
# 35                 1st      0.484868    0.000657472                  MiniVGG3
# 36                 2nd      0.454759    0.000121743                  MiniVGG3
# 37                 3rd   0.000426689     0.00627229                  MiniVGG3
# 38                 3rd     0.0346638     0.00010551                  MiniVGG3
# 39                 2nd     0.0154777      0.0320111                  MiniVGG3
# 40                 2nd     0.0187099      0.0517295                  MiniVGG3
# 41                 3rd      0.112888     0.00179264            MiniGoogLeNet1
# 42                 1st      0.484822    0.000285888                  MiniVGG3
# 43                 1st      0.484776    0.000740226                  MiniVGG3
# 44                 2nd      0.424942    0.000217639            MiniGoogLeNet1
#
#    Architecture[best] Architecture[worst] Accuracy_avg[recommended]  \
# 0            MiniVGG3     SmallSqueezeNet                   0.94405
# 1            MiniVGG1            ResNet10                    0.9079
# 2            MiniVGG3     SmallSqueezeNet                   0.95015
# 3      MiniGoogLeNet1     SmallSqueezeNet                   0.95065
# 4            MiniVGG3            ResNet10                   0.96525
# 5            MiniVGG3            ResNet10                    0.9656
# 6            MiniVGG3            ResNet10                     0.965
# 7            MiniVGG3     SmallSqueezeNet                    0.9357
# 8            MiniVGG3     SmallSqueezeNet                   0.94775
# 9      MiniGoogLeNet1     SmallSqueezeNet                    0.9746
# 10           MiniVGG3     SmallSqueezeNet                   0.96635
# 11           AlexNet1            ResNet10                   0.98415
# 12     MiniGoogLeNet1     SmallSqueezeNet                   0.98145
# 13     MiniGoogLeNet1            MiniVGG1                    0.9742
# 14           MiniVGG3     SmallSqueezeNet                   0.98115
# 15     MiniGoogLeNet1     SmallSqueezeNet                    0.9671
# 16           MiniVGG3     SmallSqueezeNet                   0.91975
# 17     MiniGoogLeNet1     SmallSqueezeNet                   0.86835
# 18           MiniVGG1     SmallSqueezeNet                    0.8859
# 19           MiniVGG1     SmallSqueezeNet                    0.8879
# 20           AlexNet1     SmallSqueezeNet                    0.8885
# 21           MiniVGG3     SmallSqueezeNet                   0.90275
# 22           AlexNet1     SmallSqueezeNet                   0.95935
# 23     MiniGoogLeNet1     SmallSqueezeNet                    0.9751
# 24           MiniVGG3     SmallSqueezeNet                   0.88815
# 25           MiniVGG3     SmallSqueezeNet                   0.82165
# 26           MiniVGG3            ResNet10                   0.90205
# 27           MiniVGG3     SmallSqueezeNet                   0.92065
# 28           MiniVGG3     SmallSqueezeNet                    0.9607
# 29     MiniGoogLeNet1            MiniVGG1                    0.9609
# 30           MiniVGG3            MiniVGG1                    0.9097
# 31           MiniVGG3     SmallSqueezeNet                   0.89015
# 32     MiniGoogLeNet1            MiniVGG1                    0.9169
# 33     MiniGoogLeNet1     SmallSqueezeNet                   0.95635
# 34           MiniVGG1     SmallSqueezeNet                    0.9649
# 35           MiniVGG3     SmallSqueezeNet                   0.94255
# 36           MiniVGG1     SmallSqueezeNet                    0.9079
# 37           MiniVGG1     SmallSqueezeNet                   0.97305
# 38     MiniGoogLeNet1     SmallSqueezeNet                   0.97425
# 39     MiniGoogLeNet1     SmallSqueezeNet                    0.9544
# 40     MiniGoogLeNet1            AlexNet1                   0.97725
# 41           MiniVGG3     SmallSqueezeNet                    0.9731
# 42           MiniVGG3     SmallSqueezeNet                   0.97825
# 43           MiniVGG3     SmallSqueezeNet                   0.97565
# 44           MiniVGG3     SmallSqueezeNet                    0.9602
#
#    Accuracy_avg[best] Accuracy_avg[worst] Precision_avg[recommended]  \
# 0             0.97175             0.87925                    0.93243
# 1             0.91925              0.8848                   0.866139
# 2             0.95015              0.9046                   0.920075
# 3             0.96365             0.91945                   0.918533
# 4               0.963              0.9447                   0.953657
# 5             0.96305             0.95595                    0.95172
# 6               0.965              0.9348                   0.942993
# 7              0.9357             0.70285                   0.904545
# 8             0.94775              0.8408                   0.915364
# 9             0.97695             0.90715                   0.959649
# 10            0.97095             0.94835                   0.946899
# 11            0.98565              0.9684                   0.975363
# 12            0.98145             0.94915                   0.971063
# 13            0.98375              0.9514                    0.95474
# 14            0.98805              0.9349                   0.967647
# 15             0.9671             0.87485                   0.952866
# 16            0.91975              0.7339                   0.875662
# 17            0.86775              0.7195                   0.821754
# 18            0.89615             0.70515                   0.832302
# 19             0.8974             0.75085                   0.850765
# 20             0.9081              0.8411                   0.835995
# 21            0.92165             0.81435                   0.874974
# 22             0.9631             0.92745                   0.938155
# 23             0.9776             0.89525                    0.96375
# 24            0.88815              0.8114                   0.832959
# 25            0.82165             0.58875                   0.772901
# 26            0.88595              0.8412                   0.861804
# 27            0.92065             0.77275                   0.893989
# 28             0.9607             0.93455                   0.944049
# 29             0.9675              0.9477                   0.941616
# 30             0.9146             0.79815                   0.880532
# 31             0.9356              0.7282                   0.830667
# 32            0.91485              0.8258                   0.896137
# 33             0.9783             0.94805                   0.944302
# 34            0.98215              0.9261                   0.955826
# 35            0.94255              0.8091                   0.907929
# 36             0.9101              0.7447                   0.875736
# 37              0.979              0.8869                    0.95808
# 38             0.9784             0.91895                   0.959492
# 39            0.97125             0.90895                   0.948642
# 40             0.9813             0.97055                   0.971923
# 41             0.9801             0.93615                   0.969426
# 42            0.97825             0.92565                   0.970667
# 43            0.97565             0.88885                   0.963455
# 44             0.9609             0.85705                   0.946488
#
#    Precision_avg[best] Precision_avg[worst] Recall_avg[recommended]  \
# 0             0.953785              0.85842                  0.9128
# 1             0.878482             0.843588                  0.9305
# 2             0.920075             0.872486                  0.9716
# 3             0.945979              0.89732                  0.9789
# 4             0.945098             0.923633                  0.9553
# 5             0.934987             0.937775                   0.961
# 6             0.942993             0.909471                  0.9795
# 7             0.904545             0.667966                  0.9446
# 8             0.915364             0.816722                  0.9735
# 9             0.961333             0.890751                  0.9831
# 10            0.958614             0.925851                  0.9772
# 11            0.977944             0.952347                  0.9866
# 12            0.971063              0.93106                  0.9847
# 13            0.976103             0.913928                   0.992
# 14            0.979809             0.905675                  0.9916
# 15            0.952866             0.846268                  0.9646
# 16            0.875662             0.701036                  0.9619
# 17            0.817011             0.658157                  0.8637
# 18             0.83972             0.653047                  0.9324
# 19            0.853868             0.690622                  0.8725
# 20            0.859135             0.803023                  0.9581
# 21              0.8965             0.765699                  0.8718
# 22            0.948757             0.901121                  0.9671
# 23            0.970967             0.866322                  0.9743
# 24            0.832959              0.76648                   0.936
# 25            0.772901             0.563398                  0.7882
# 26             0.82975             0.792836                  0.9095
# 27            0.893989             0.741858                  0.9026
# 28            0.944049             0.907327                  0.9578
# 29            0.954061               0.9375                  0.9657
# 30             0.89467             0.791662                  0.8882
# 31            0.897821             0.695101                  0.9589
# 32             0.87906             0.810743                   0.882
# 33            0.966013             0.929503                  0.9383
# 34            0.979045             0.896682                  0.9495
# 35            0.907929             0.772707                  0.9692
# 36            0.880114             0.713047                  0.8943
# 37            0.967914             0.858686                  0.9784
# 38            0.968089             0.901332                  0.9803
# 39            0.958213              0.88324                  0.9207
# 40            0.974671              0.96372                  0.9655
# 41            0.976707             0.921241                  0.9537
# 42            0.970667             0.896233                  0.9724
# 43            0.963455             0.866129                   0.978
# 44            0.942395             0.828032                  0.9497
#
#    Recall_avg[best] Recall_avg[worst] F1_avg[recommended] F1_avg[best]  \
# 0            0.9827             0.808            0.938552      0.97206
# 1            0.9418            0.8753            0.910156     0.921148
# 2            0.9716            0.8927            0.951379     0.951379
# 3            0.9657            0.8919            0.952252     0.963716
# 4            0.9663            0.9363             0.96488     0.963215
# 5            0.9913            0.9518            0.964927     0.964203
# 6            0.9795            0.9278            0.965587     0.965587
# 7            0.9446            0.6881            0.936251     0.936251
# 8            0.9735              0.94            0.949271     0.949271
# 9            0.9875            0.8509            0.975034     0.977209
# 10           0.9681            0.9509            0.966924     0.970859
# 11           0.9874            0.9714            0.984188     0.985685
# 12           0.9847            0.9409            0.981513     0.981513
# 13           0.9834            0.9955            0.974786     0.983729
# 14           0.9933            0.9697            0.981418     0.988126
# 15           0.9646            0.8993            0.967008     0.967008
# 16           0.9619            0.7066            0.923908     0.923908
# 17           0.8801            0.7816            0.867331      0.86927
# 18           0.9525            0.7719            0.891669     0.901828
# 19           0.9122            0.8391            0.884585     0.898548
# 20           0.9475            0.7972            0.898682     0.911645
# 21           0.9023            0.8688            0.894678      0.91931
# 22            0.957            0.9252             0.95969      0.96283
# 23           0.9689            0.8701            0.975079     0.977375
# 24            0.936            0.7526            0.893529     0.893529
# 25           0.7882            0.7854            0.814826     0.814826
# 26           0.9529            0.8203            0.902998     0.894687
# 27           0.9026             0.753            0.919069     0.919069
# 28           0.9578            0.9369            0.960557     0.960557
# 29           0.9642            0.9172            0.961127     0.967414
# 30           0.8743              0.61            0.906875     0.910139
# 31           0.9662            0.6849            0.897537     0.937796
# 32            0.922            0.6852             0.91313     0.915858
# 33           0.9829             0.938            0.955176     0.978432
# 34           0.9706            0.9599             0.96248     0.981931
# 35           0.9692            0.7443            0.944201     0.944201
# 36           0.8919            0.6086            0.906103     0.908171
# 37           0.9813            0.9639            0.973214      0.97905
# 38           0.9784            0.8821             0.97443     0.978396
# 39           0.9703            0.8956            0.952095     0.971219
# 40           0.9763            0.9552            0.976912     0.981136
# 41           0.9671             0.914            0.971268     0.979792
# 42           0.9724            0.9546             0.97812      0.97812
# 43            0.978            0.9128            0.975767     0.975767
# 44           0.9624            0.9097             0.95973     0.960918
#
#    F1_avg[worst]
# 0       0.824166
# 1       0.883662
# 2       0.900057
# 3        0.91518
# 4       0.944177
# 5       0.955717
# 6       0.934305
# 7       0.669603
# 8        0.87413
# 9       0.856313
# 10      0.948735
# 11      0.968499
# 12      0.946836
# 13      0.953729
# 14      0.940333
# 15      0.882756
# 16      0.683072
# 17      0.731731
# 18      0.719914
# 19      0.770146
# 20      0.829249
# 21      0.828165
# 22      0.926834
# 23      0.847831
# 24      0.789134
# 25      0.654599
# 26      0.835946
# 27      0.748492
# 28      0.933786
# 29      0.945549
# 30       0.74675
# 31      0.641894
# 32      0.795888
# 33      0.945807
# 34      0.932368
# 35      0.749923
# 36      0.653758
# 37      0.907294
# 38      0.911719
# 39      0.905728
# 40      0.969897
# 41      0.934866
# 42      0.930716
# 43      0.897996
# 44      0.874623

# %%
knn_results_df.groupby('Recommendation_rank').Task.count()
# Out:
# Recommendation_rank
# 1st    14
# 2nd    19
# 3rd     6
# 4th     6
# Name: Task, dtype: int64

# %%
svm_results_df
# Out:
#                    Task                              Ranking_architectures  \
# 0   airplane-automobile  MiniVGG3, MiniVGG1, AlexNet1, MiniGoogLeNet1, ...
# 1         airplane-bird  MiniVGG1, MiniGoogLeNet1, MiniVGG3, AlexNet1, ...
# 2          airplane-cat  MiniVGG3, MiniVGG1, AlexNet1, ResNet10, MiniGo...
# 3         airplane-deer  MiniGoogLeNet1, MiniVGG3, AlexNet1, ResNet10, ...
# 4          airplane-dog  MiniVGG3, MiniGoogLeNet1, AlexNet1, MiniVGG1, ...
# 5         airplane-frog  MiniVGG3, AlexNet1, MiniGoogLeNet1, SmallSquee...
# 6        airplane-horse  MiniVGG3, MiniVGG1, MiniGoogLeNet1, AlexNet1, ...
# 7         airplane-ship  MiniVGG3, AlexNet1, MiniGoogLeNet1, MiniVGG1, ...
# 8        airplane-truck  MiniVGG3, AlexNet1, MiniGoogLeNet1, MiniVGG1, ...
# 9       automobile-bird  MiniGoogLeNet1, MiniVGG3, AlexNet1, MiniVGG1, ...
# 10       automobile-cat  MiniVGG3, MiniGoogLeNet1, AlexNet1, MiniVGG1, ...
# 11      automobile-deer  AlexNet1, MiniGoogLeNet1, MiniVGG3, SmallSquee...
# 12       automobile-dog  MiniGoogLeNet1, MiniVGG3, MiniVGG1, AlexNet1, ...
# 13      automobile-frog  MiniGoogLeNet1, MiniVGG3, ResNet10, AlexNet1, ...
# 14     automobile-horse  MiniVGG3, MiniGoogLeNet1, AlexNet1, MiniVGG1, ...
# 15      automobile-ship  MiniGoogLeNet1, AlexNet1, MiniVGG3, ResNet10, ...
# 16     automobile-truck  MiniVGG3, AlexNet1, MiniGoogLeNet1, MiniVGG1, ...
# 17             bird-cat  MiniGoogLeNet1, MiniVGG3, AlexNet1, MiniVGG1, ...
# 18            bird-deer  MiniVGG1, MiniVGG3, AlexNet1, MiniGoogLeNet1, ...
# 19             bird-dog  MiniVGG1, AlexNet1, MiniVGG3, MiniGoogLeNet1, ...
# 20            bird-frog  AlexNet1, MiniVGG3, MiniGoogLeNet1, MiniVGG1, ...
# 21           bird-horse  MiniVGG3, MiniVGG1, AlexNet1, MiniGoogLeNet1, ...
# 22            bird-ship  AlexNet1, MiniVGG3, MiniGoogLeNet1, MiniVGG1, ...
# 23           bird-truck  MiniGoogLeNet1, MiniVGG3, MiniVGG1, AlexNet1, ...
# 24             cat-deer  MiniVGG3, AlexNet1, MiniGoogLeNet1, MiniVGG1, ...
# 25              cat-dog  MiniVGG3, MiniGoogLeNet1, AlexNet1, MiniVGG1, ...
# 26             cat-frog  MiniVGG3, MiniGoogLeNet1, AlexNet1, MiniVGG1, ...
# 27            cat-horse  MiniVGG3, AlexNet1, MiniGoogLeNet1, MiniVGG1, ...
# 28             cat-ship  MiniVGG3, AlexNet1, MiniVGG1, ResNet10, MiniGo...
# 29            cat-truck  MiniGoogLeNet1, MiniVGG3, AlexNet1, ResNet10, ...
# 30             deer-dog  MiniVGG3, MiniGoogLeNet1, AlexNet1, ResNet10, ...
# 31            deer-frog  MiniVGG3, MiniGoogLeNet1, AlexNet1, MiniVGG1, ...
# 32           deer-horse  MiniGoogLeNet1, MiniVGG3, AlexNet1, SmallSquee...
# 33            deer-ship  MiniGoogLeNet1, MiniVGG3, AlexNet1, MiniVGG1, ...
# 34           deer-truck  MiniVGG1, MiniVGG3, AlexNet1, MiniGoogLeNet1, ...
# 35             dog-frog  MiniVGG3, AlexNet1, MiniGoogLeNet1, MiniVGG1, ...
# 36            dog-horse  MiniVGG1, MiniVGG3, MiniGoogLeNet1, AlexNet1, ...
# 37             dog-ship  MiniVGG1, MiniGoogLeNet1, MiniVGG3, AlexNet1, ...
# 38            dog-truck  MiniGoogLeNet1, MiniVGG1, MiniVGG3, ResNet10, ...
# 39           frog-horse  MiniGoogLeNet1, MiniVGG3, ResNet10, MiniVGG1, ...
# 40            frog-ship  MiniGoogLeNet1, MiniVGG3, MiniVGG1, SmallSquee...
# 41           frog-truck  MiniVGG3, ResNet10, MiniGoogLeNet1, MiniVGG1, ...
# 42           horse-ship  MiniVGG3, AlexNet1, MiniVGG1, MiniGoogLeNet1, ...
# 43          horse-truck  MiniVGG3, MiniVGG1, MiniGoogLeNet1, AlexNet1, ...
# 44           ship-truck  MiniVGG3, MiniGoogLeNet1, AlexNet1, MiniVGG1, ...
#
#    Recommendation_rank P_value[best] P_value[worst] Architecture[recommended]  \
# 0                  1st      0.484868    0.000503988                  MiniVGG3
# 1                  3rd      0.298282       0.012874                  MiniVGG3
# 2                  1st      0.484822     0.00109688                  MiniVGG3
# 3                  2nd     0.0376108      0.0141233                  MiniVGG3
# 4                  1st      0.484868    0.000641022                  MiniVGG3
# 5                  1st      0.484868      0.0292958                  MiniVGG3
# 6                  1st      0.484822    9.03174e-05                  MiniVGG3
# 7                  1st      0.484822    0.000122402                  MiniVGG3
# 8                  1st      0.484868     0.00505429                  MiniVGG3
# 9                  2nd      0.324704    0.000743288                  MiniVGG3
# 10                 1st      0.484822    0.000104354                  MiniVGG3
# 11                 3rd     0.0139751      0.0045152                  MiniVGG3
# 12                 2nd      0.120307      0.0012391                  MiniVGG3
# 13                 2nd    0.00173035     0.00563412                  MiniVGG3
# 14                 1st      0.484822    0.000188601                  MiniVGG3
# 15                 3rd      0.136247     0.00256272                  MiniVGG3
# 16                 1st      0.484868     0.00289768                  MiniVGG3
# 17                 2nd      0.410265    9.13359e-05                  MiniVGG3
# 18                 2nd      0.338678    0.000503988                  MiniVGG3
# 19                 3rd      0.285375      0.0003333                  MiniVGG3
# 20                 2nd      0.484919      0.0205869                  MiniVGG3
# 21                 1st      0.484822    0.000962254                  MiniVGG3
# 22                 2nd       0.21333     0.00287932                  MiniVGG3
# 23                 2nd     0.0242566    9.03174e-05                  MiniVGG3
# 24                 1st      0.484868    0.000497378                  MiniVGG3
# 25                 1st      0.484868    8.93072e-05                  MiniVGG3
# 26                 1st      0.484868      0.0320111                  MiniVGG3
# 27                 1st      0.484822    9.08256e-05                  MiniVGG3
# 28                 1st      0.484822     0.00287016                  MiniVGG3
# 29                 2nd      0.144505      0.0188177                  MiniVGG3
# 30                 1st      0.484868    9.13359e-05                  MiniVGG3
# 31                 1st      0.484822    0.000499575                  MiniVGG3
# 32                 2nd      0.338792    9.08256e-05                  MiniVGG3
# 33                 2nd    0.00122514      0.0154461                  MiniVGG3
# 34                 2nd      0.190897    0.000499575                  MiniVGG3
# 35                 1st      0.484868    0.000657472                  MiniVGG3
# 36                 2nd      0.454759    0.000121743                  MiniVGG3
# 37                 3rd   0.000426689     0.00627229                  MiniVGG3
# 38                 3rd     0.0346638     0.00010551                  MiniVGG3
# 39                 2nd     0.0154777      0.0320111                  MiniVGG3
# 40                 2nd     0.0187099      0.0517295                  MiniVGG3
# 41                 1st      0.484822    0.000842869                  MiniVGG3
# 42                 1st      0.484822    0.000285888                  MiniVGG3
# 43                 1st      0.484776    0.000740226                  MiniVGG3
# 44                 1st      0.484822    0.000217639                  MiniVGG3
#
#    Architecture[best] Architecture[worst] Accuracy_avg[recommended]  \
# 0            MiniVGG3     SmallSqueezeNet                   0.97175
# 1            MiniVGG1            ResNet10                    0.9079
# 2            MiniVGG3     SmallSqueezeNet                   0.95015
# 3      MiniGoogLeNet1     SmallSqueezeNet                   0.95065
# 4            MiniVGG3            ResNet10                     0.963
# 5            MiniVGG3            ResNet10                   0.96305
# 6            MiniVGG3            ResNet10                     0.965
# 7            MiniVGG3     SmallSqueezeNet                    0.9357
# 8            MiniVGG3     SmallSqueezeNet                   0.94775
# 9      MiniGoogLeNet1     SmallSqueezeNet                    0.9746
# 10           MiniVGG3     SmallSqueezeNet                   0.97095
# 11           AlexNet1            ResNet10                    0.9778
# 12     MiniGoogLeNet1     SmallSqueezeNet                   0.97915
# 13     MiniGoogLeNet1            MiniVGG1                    0.9742
# 14           MiniVGG3     SmallSqueezeNet                   0.98805
# 15     MiniGoogLeNet1     SmallSqueezeNet                   0.95755
# 16           MiniVGG3     SmallSqueezeNet                   0.91975
# 17     MiniGoogLeNet1     SmallSqueezeNet                   0.86835
# 18           MiniVGG1     SmallSqueezeNet                    0.8859
# 19           MiniVGG1     SmallSqueezeNet                    0.8879
# 20           AlexNet1     SmallSqueezeNet                    0.8885
# 21           MiniVGG3     SmallSqueezeNet                   0.92165
# 22           AlexNet1     SmallSqueezeNet                   0.96505
# 23     MiniGoogLeNet1     SmallSqueezeNet                    0.9751
# 24           MiniVGG3     SmallSqueezeNet                   0.88815
# 25           MiniVGG3     SmallSqueezeNet                   0.82165
# 26           MiniVGG3            ResNet10                   0.88595
# 27           MiniVGG3     SmallSqueezeNet                   0.92065
# 28           MiniVGG3     SmallSqueezeNet                    0.9607
# 29     MiniGoogLeNet1            MiniVGG1                    0.9609
# 30           MiniVGG3            MiniVGG1                    0.9146
# 31           MiniVGG3     SmallSqueezeNet                    0.9356
# 32     MiniGoogLeNet1            MiniVGG1                    0.9169
# 33     MiniGoogLeNet1     SmallSqueezeNet                   0.96855
# 34           MiniVGG1     SmallSqueezeNet                    0.9802
# 35           MiniVGG3     SmallSqueezeNet                   0.94255
# 36           MiniVGG1     SmallSqueezeNet                    0.9079
# 37           MiniVGG1     SmallSqueezeNet                   0.97305
# 38     MiniGoogLeNet1     SmallSqueezeNet                   0.97425
# 39     MiniGoogLeNet1     SmallSqueezeNet                    0.9544
# 40     MiniGoogLeNet1            AlexNet1                   0.97725
# 41           MiniVGG3     SmallSqueezeNet                    0.9801
# 42           MiniVGG3     SmallSqueezeNet                   0.97825
# 43           MiniVGG3     SmallSqueezeNet                   0.97565
# 44           MiniVGG3     SmallSqueezeNet                    0.9609
#
#    Accuracy_avg[best] Accuracy_avg[worst] Precision_avg[recommended]  \
# 0             0.97175             0.87925                   0.953785
# 1             0.91925              0.8848                   0.866139
# 2             0.95015              0.9046                   0.920075
# 3             0.96365             0.91945                   0.918533
# 4               0.963              0.9447                   0.945098
# 5             0.96305             0.95595                   0.934987
# 6               0.965              0.9348                   0.942993
# 7              0.9357             0.70285                   0.904545
# 8             0.94775              0.8408                   0.915364
# 9             0.97695             0.90715                   0.959649
# 10            0.97095             0.94835                   0.958614
# 11            0.98565              0.9684                   0.961956
# 12            0.98145             0.94915                   0.969931
# 13            0.98375              0.9514                    0.95474
# 14            0.98805              0.9349                   0.979809
# 15             0.9671             0.87485                   0.947163
# 16            0.91975              0.7339                   0.875662
# 17            0.86775              0.7195                   0.821754
# 18            0.89615             0.70515                   0.832302
# 19             0.8974             0.75085                   0.850765
# 20             0.9081              0.8411                   0.835995
# 21            0.92165             0.81435                     0.8965
# 22             0.9631             0.92745                   0.955027
# 23             0.9776             0.89525                    0.96375
# 24            0.88815              0.8114                   0.832959
# 25            0.82165             0.58875                   0.772901
# 26            0.88595              0.8412                    0.82975
# 27            0.92065             0.77275                   0.893989
# 28             0.9607             0.93455                   0.944049
# 29             0.9675              0.9477                   0.941616
# 30             0.9146             0.79815                    0.89467
# 31             0.9356              0.7282                   0.897821
# 32            0.91485              0.8258                   0.896137
# 33             0.9783             0.94805                   0.956406
# 34            0.98215              0.9261                   0.973992
# 35            0.94255              0.8091                   0.907929
# 36             0.9101              0.7447                   0.875736
# 37              0.979              0.8869                    0.95808
# 38             0.9784             0.91895                   0.959492
# 39            0.97125             0.90895                   0.948642
# 40             0.9813             0.97055                   0.971923
# 41             0.9801             0.93615                   0.976707
# 42            0.97825             0.92565                   0.970667
# 43            0.97565             0.88885                   0.963455
# 44             0.9609             0.85705                   0.942395
#
#    Precision_avg[best] Precision_avg[worst] Recall_avg[recommended]  \
# 0             0.953785              0.85842                  0.9827
# 1             0.878482             0.843588                  0.9305
# 2             0.920075             0.872486                  0.9716
# 3             0.945979              0.89732                  0.9789
# 4             0.945098             0.923633                  0.9663
# 5             0.934987             0.937775                  0.9913
# 6             0.942993             0.909471                  0.9795
# 7             0.904545             0.667966                  0.9446
# 8             0.915364             0.816722                  0.9735
# 9             0.961333             0.890751                  0.9831
# 10            0.958614             0.925851                  0.9681
# 11            0.977944             0.952347                  0.9908
# 12            0.971063              0.93106                  0.9778
# 13            0.976103             0.913928                   0.992
# 14            0.979809             0.905675                  0.9933
# 15            0.952866             0.846268                  0.9371
# 16            0.875662             0.701036                  0.9619
# 17            0.817011             0.658157                  0.8637
# 18             0.83972             0.653047                  0.9324
# 19            0.853868             0.690622                  0.8725
# 20            0.859135             0.803023                  0.9581
# 21              0.8965             0.765699                  0.9023
# 22            0.948757             0.901121                  0.9512
# 23            0.970967             0.866322                  0.9743
# 24            0.832959              0.76648                   0.936
# 25            0.772901             0.563398                  0.7882
# 26             0.82975             0.792836                  0.9529
# 27            0.893989             0.741858                  0.9026
# 28            0.944049             0.907327                  0.9578
# 29            0.954061               0.9375                  0.9657
# 30             0.89467             0.791662                  0.8743
# 31            0.897821             0.695101                  0.9662
# 32             0.87906             0.810743                   0.882
# 33            0.966013             0.929503                  0.9632
# 34            0.979045             0.896682                  0.9732
# 35            0.907929             0.772707                  0.9692
# 36            0.880114             0.713047                  0.8943
# 37            0.967914             0.858686                  0.9784
# 38            0.968089             0.901332                  0.9803
# 39            0.958213              0.88324                  0.9207
# 40            0.974671              0.96372                  0.9655
# 41            0.976707             0.921241                  0.9671
# 42            0.970667             0.896233                  0.9724
# 43            0.963455             0.866129                   0.978
# 44            0.942395             0.828032                  0.9624
#
#    Recall_avg[best] Recall_avg[worst] F1_avg[recommended] F1_avg[best]  \
# 0            0.9827             0.808             0.97206      0.97206
# 1            0.9418            0.8753            0.910156     0.921148
# 2            0.9716            0.8927            0.951379     0.951379
# 3            0.9657            0.8919            0.952252     0.963716
# 4            0.9663            0.9363            0.963215     0.963215
# 5            0.9913            0.9518            0.964203     0.964203
# 6            0.9795            0.9278            0.965587     0.965587
# 7            0.9446            0.6881            0.936251     0.936251
# 8            0.9735              0.94            0.949271     0.949271
# 9            0.9875            0.8509            0.975034     0.977209
# 10           0.9681            0.9509            0.970859     0.970859
# 11           0.9874            0.9714            0.978224     0.985685
# 12           0.9847            0.9409            0.979111     0.981513
# 13           0.9834            0.9955            0.974786     0.983729
# 14           0.9933            0.9697            0.988126     0.988126
# 15           0.9646            0.8993            0.955923     0.967008
# 16           0.9619            0.7066            0.923908     0.923908
# 17           0.8801            0.7816            0.867331      0.86927
# 18           0.9525            0.7719            0.891669     0.901828
# 19           0.9122            0.8391            0.884585     0.898548
# 20           0.9475            0.7972            0.898682     0.911645
# 21           0.9023            0.8688             0.91931      0.91931
# 22            0.957            0.9252             0.96449      0.96283
# 23           0.9689            0.8701            0.975079     0.977375
# 24            0.936            0.7526            0.893529     0.893529
# 25           0.7882            0.7854            0.814826     0.814826
# 26           0.9529            0.8203            0.894687     0.894687
# 27           0.9026             0.753            0.919069     0.919069
# 28           0.9578            0.9369            0.960557     0.960557
# 29           0.9642            0.9172            0.961127     0.967414
# 30           0.8743              0.61            0.910139     0.910139
# 31           0.9662            0.6849            0.937796     0.937796
# 32            0.922            0.6852             0.91313     0.915858
# 33           0.9829             0.938            0.968339     0.978432
# 34           0.9706            0.9599            0.980049     0.981931
# 35           0.9692            0.7443            0.944201     0.944201
# 36           0.8919            0.6086            0.906103     0.908171
# 37           0.9813            0.9639            0.973214      0.97905
# 38           0.9784            0.8821             0.97443     0.978396
# 39           0.9703            0.8956            0.952095     0.971219
# 40           0.9763            0.9552            0.976912     0.981136
# 41           0.9671             0.914            0.979792     0.979792
# 42           0.9724            0.9546             0.97812      0.97812
# 43            0.978            0.9128            0.975767     0.975767
# 44           0.9624            0.9097            0.960918     0.960918
#
#    F1_avg[worst]
# 0       0.824166
# 1       0.883662
# 2       0.900057
# 3        0.91518
# 4       0.944177
# 5       0.955717
# 6       0.934305
# 7       0.669603
# 8        0.87413
# 9       0.856313
# 10      0.948735
# 11      0.968499
# 12      0.946836
# 13      0.953729
# 14      0.940333
# 15      0.882756
# 16      0.683072
# 17      0.731731
# 18      0.719914
# 19      0.770146
# 20      0.829249
# 21      0.828165
# 22      0.926834
# 23      0.847831
# 24      0.789134
# 25      0.654599
# 26      0.835946
# 27      0.748492
# 28      0.933786
# 29      0.945549
# 30       0.74675
# 31      0.641894
# 32      0.795888
# 33      0.945807
# 34      0.932368
# 35      0.749923
# 36      0.653758
# 37      0.907294
# 38      0.911719
# 39      0.905728
# 40      0.969897
# 41      0.934866
# 42      0.930716
# 43      0.897996
# 44      0.874623

# %%
svm_results_df.groupby('Recommendation_rank').Task.count()
# Out:
# Recommendation_rank
# 1st    23
# 2nd    16
# 3rd     6
# Name: Task, dtype: int64

# %%
rf_results_df
# Out:
#                    Task                              Ranking_architectures  \
# 0   airplane-automobile  MiniVGG3, MiniVGG1, AlexNet1, MiniGoogLeNet1, ...
# 1         airplane-bird  MiniVGG1, MiniGoogLeNet1, MiniVGG3, AlexNet1, ...
# 2          airplane-cat  MiniVGG3, MiniVGG1, AlexNet1, ResNet10, MiniGo...
# 3         airplane-deer  MiniGoogLeNet1, MiniVGG3, AlexNet1, ResNet10, ...
# 4          airplane-dog  MiniVGG3, MiniGoogLeNet1, AlexNet1, MiniVGG1, ...
# 5         airplane-frog  MiniVGG3, AlexNet1, MiniGoogLeNet1, SmallSquee...
# 6        airplane-horse  MiniVGG3, MiniVGG1, MiniGoogLeNet1, AlexNet1, ...
# 7         airplane-ship  MiniVGG3, AlexNet1, MiniGoogLeNet1, MiniVGG1, ...
# 8        airplane-truck  MiniVGG3, AlexNet1, MiniGoogLeNet1, MiniVGG1, ...
# 9       automobile-bird  MiniGoogLeNet1, MiniVGG3, AlexNet1, MiniVGG1, ...
# 10       automobile-cat  MiniVGG3, MiniGoogLeNet1, AlexNet1, MiniVGG1, ...
# 11      automobile-deer  AlexNet1, MiniGoogLeNet1, MiniVGG3, SmallSquee...
# 12       automobile-dog  MiniGoogLeNet1, MiniVGG3, MiniVGG1, AlexNet1, ...
# 13      automobile-frog  MiniGoogLeNet1, MiniVGG3, ResNet10, AlexNet1, ...
# 14     automobile-horse  MiniVGG3, MiniGoogLeNet1, AlexNet1, MiniVGG1, ...
# 15      automobile-ship  MiniGoogLeNet1, AlexNet1, MiniVGG3, ResNet10, ...
# 16     automobile-truck  MiniVGG3, AlexNet1, MiniGoogLeNet1, MiniVGG1, ...
# 17             bird-cat  MiniGoogLeNet1, MiniVGG3, AlexNet1, MiniVGG1, ...
# 18            bird-deer  MiniVGG1, MiniVGG3, AlexNet1, MiniGoogLeNet1, ...
# 19             bird-dog  MiniVGG1, AlexNet1, MiniVGG3, MiniGoogLeNet1, ...
# 20            bird-frog  AlexNet1, MiniVGG3, MiniGoogLeNet1, MiniVGG1, ...
# 21           bird-horse  MiniVGG3, MiniVGG1, AlexNet1, MiniGoogLeNet1, ...
# 22            bird-ship  AlexNet1, MiniVGG3, MiniGoogLeNet1, MiniVGG1, ...
# 23           bird-truck  MiniGoogLeNet1, MiniVGG3, MiniVGG1, AlexNet1, ...
# 24             cat-deer  MiniVGG3, AlexNet1, MiniGoogLeNet1, MiniVGG1, ...
# 25              cat-dog  MiniVGG3, MiniGoogLeNet1, AlexNet1, MiniVGG1, ...
# 26             cat-frog  MiniVGG3, MiniGoogLeNet1, AlexNet1, MiniVGG1, ...
# 27            cat-horse  MiniVGG3, AlexNet1, MiniGoogLeNet1, MiniVGG1, ...
# 28             cat-ship  MiniVGG3, AlexNet1, MiniVGG1, ResNet10, MiniGo...
# 29            cat-truck  MiniGoogLeNet1, MiniVGG3, AlexNet1, ResNet10, ...
# 30             deer-dog  MiniVGG3, MiniGoogLeNet1, AlexNet1, ResNet10, ...
# 31            deer-frog  MiniVGG3, MiniGoogLeNet1, AlexNet1, MiniVGG1, ...
# 32           deer-horse  MiniGoogLeNet1, MiniVGG3, AlexNet1, SmallSquee...
# 33            deer-ship  MiniGoogLeNet1, MiniVGG3, AlexNet1, MiniVGG1, ...
# 34           deer-truck  MiniVGG1, MiniVGG3, AlexNet1, MiniGoogLeNet1, ...
# 35             dog-frog  MiniVGG3, AlexNet1, MiniGoogLeNet1, MiniVGG1, ...
# 36            dog-horse  MiniVGG1, MiniVGG3, MiniGoogLeNet1, AlexNet1, ...
# 37             dog-ship  MiniVGG1, MiniGoogLeNet1, MiniVGG3, AlexNet1, ...
# 38            dog-truck  MiniGoogLeNet1, MiniVGG1, MiniVGG3, ResNet10, ...
# 39           frog-horse  MiniGoogLeNet1, MiniVGG3, ResNet10, MiniVGG1, ...
# 40            frog-ship  MiniGoogLeNet1, MiniVGG3, MiniVGG1, SmallSquee...
# 41           frog-truck  MiniVGG3, ResNet10, MiniGoogLeNet1, MiniVGG1, ...
# 42           horse-ship  MiniVGG3, AlexNet1, MiniVGG1, MiniGoogLeNet1, ...
# 43          horse-truck  MiniVGG3, MiniVGG1, MiniGoogLeNet1, AlexNet1, ...
# 44           ship-truck  MiniVGG3, MiniGoogLeNet1, AlexNet1, MiniVGG1, ...
#
#    Recommendation_rank P_value[best] P_value[worst] Architecture[recommended]  \
# 0                  1st      0.484868    0.000503988                  MiniVGG3
# 1                  3rd      0.298282       0.012874                  MiniVGG3
# 2                  1st      0.484822     0.00109688                  MiniVGG3
# 3                  2nd     0.0376108      0.0141233                  MiniVGG3
# 4                  1st      0.484868    0.000641022                  MiniVGG3
# 5                  1st      0.484868      0.0292958                  MiniVGG3
# 6                  1st      0.484822    9.03174e-05                  MiniVGG3
# 7                  1st      0.484822    0.000122402                  MiniVGG3
# 8                  1st      0.484868     0.00505429                  MiniVGG3
# 9                  1st      0.484822    0.000501778            MiniGoogLeNet1
# 10                 2nd      0.285012    0.000954682            MiniGoogLeNet1
# 11                 2nd     0.0736901    8.78078e-05            MiniGoogLeNet1
# 12                 1st      0.484822    0.000250809            MiniGoogLeNet1
# 13                 2nd    0.00173035     0.00563412                  MiniVGG3
# 14                 2nd     0.0170456     0.00286102            MiniGoogLeNet1
# 15                 1st      0.484868    0.000141807            MiniGoogLeNet1
# 16                 1st      0.484868     0.00289768                  MiniVGG3
# 17                 2nd      0.410265    9.13359e-05                  MiniVGG3
# 18                 1st      0.484868    9.13359e-05                  MiniVGG1
# 19                 1st      0.484868    9.13359e-05                  MiniVGG1
# 20                 3rd           0.5    0.000853125            MiniGoogLeNet1
# 21                 4th     0.0753098     0.00862873            MiniGoogLeNet1
# 22                 3rd      0.366672     0.00774334            MiniGoogLeNet1
# 23                 2nd     0.0242566    9.03174e-05                  MiniVGG3
# 24                 1st      0.484868    0.000497378                  MiniVGG3
# 25                 1st      0.484868    8.93072e-05                  MiniVGG3
# 26                 1st      0.484868      0.0320111                  MiniVGG3
# 27                 1st      0.484822    9.08256e-05                  MiniVGG3
# 28                 1st      0.484822     0.00287016                  MiniVGG3
# 29                 2nd      0.144505      0.0188177                  MiniVGG3
# 30                 6th   9.13359e-05       0.484868                  MiniVGG1
# 31                 2nd     0.0924414    0.000497378            MiniGoogLeNet1
# 32                 6th   9.08256e-05       0.484822                  MiniVGG1
# 33                 2nd    0.00122514      0.0154461                  MiniVGG3
# 34                 4th     0.0918599      0.0104943            MiniGoogLeNet1
# 35                 1st      0.484868    0.000657472                  MiniVGG3
# 36                 2nd      0.454759    0.000121743                  MiniVGG3
# 37                 3rd   0.000426689     0.00627229                  MiniVGG3
# 38                 1st      0.484868    9.13359e-05            MiniGoogLeNet1
# 39                 2nd     0.0154777      0.0320111                  MiniVGG3
# 40                 2nd     0.0187099      0.0517295                  MiniVGG3
# 41                 3rd      0.112888     0.00179264            MiniGoogLeNet1
# 42                 4th       0.22459     0.00109688            MiniGoogLeNet1
# 43                 1st      0.484776    0.000740226                  MiniVGG3
# 44                 2nd      0.424942    0.000217639            MiniGoogLeNet1
#
#    Architecture[best] Architecture[worst] Accuracy_avg[recommended]  \
# 0            MiniVGG3     SmallSqueezeNet                   0.97175
# 1            MiniVGG1            ResNet10                    0.9079
# 2            MiniVGG3     SmallSqueezeNet                   0.95015
# 3      MiniGoogLeNet1     SmallSqueezeNet                   0.95065
# 4            MiniVGG3            ResNet10                     0.963
# 5            MiniVGG3            ResNet10                   0.96305
# 6            MiniVGG3            ResNet10                     0.965
# 7            MiniVGG3     SmallSqueezeNet                    0.9357
# 8            MiniVGG3     SmallSqueezeNet                   0.94775
# 9      MiniGoogLeNet1     SmallSqueezeNet                   0.97695
# 10           MiniVGG3     SmallSqueezeNet                   0.96635
# 11           AlexNet1            ResNet10                   0.98415
# 12     MiniGoogLeNet1     SmallSqueezeNet                   0.98145
# 13     MiniGoogLeNet1            MiniVGG1                    0.9742
# 14           MiniVGG3     SmallSqueezeNet                   0.98115
# 15     MiniGoogLeNet1     SmallSqueezeNet                    0.9671
# 16           MiniVGG3     SmallSqueezeNet                   0.91975
# 17     MiniGoogLeNet1     SmallSqueezeNet                   0.86835
# 18           MiniVGG1     SmallSqueezeNet                   0.89615
# 19           MiniVGG1     SmallSqueezeNet                    0.8974
# 20           AlexNet1     SmallSqueezeNet                   0.90545
# 21           MiniVGG3     SmallSqueezeNet                   0.90275
# 22           AlexNet1     SmallSqueezeNet                    0.9618
# 23     MiniGoogLeNet1     SmallSqueezeNet                    0.9751
# 24           MiniVGG3     SmallSqueezeNet                   0.88815
# 25           MiniVGG3     SmallSqueezeNet                   0.82165
# 26           MiniVGG3            ResNet10                   0.88595
# 27           MiniVGG3     SmallSqueezeNet                   0.92065
# 28           MiniVGG3     SmallSqueezeNet                    0.9607
# 29     MiniGoogLeNet1            MiniVGG1                    0.9609
# 30           MiniVGG3            MiniVGG1                   0.79815
# 31           MiniVGG3     SmallSqueezeNet                   0.92905
# 32     MiniGoogLeNet1            MiniVGG1                    0.8258
# 33     MiniGoogLeNet1     SmallSqueezeNet                   0.96855
# 34           MiniVGG1     SmallSqueezeNet                    0.9649
# 35           MiniVGG3     SmallSqueezeNet                   0.94255
# 36           MiniVGG1     SmallSqueezeNet                    0.9079
# 37           MiniVGG1     SmallSqueezeNet                   0.97305
# 38     MiniGoogLeNet1     SmallSqueezeNet                    0.9784
# 39     MiniGoogLeNet1     SmallSqueezeNet                    0.9544
# 40     MiniGoogLeNet1            AlexNet1                   0.97725
# 41           MiniVGG3     SmallSqueezeNet                    0.9731
# 42           MiniVGG3     SmallSqueezeNet                   0.96425
# 43           MiniVGG3     SmallSqueezeNet                   0.97565
# 44           MiniVGG3     SmallSqueezeNet                    0.9602
#
#    Accuracy_avg[best] Accuracy_avg[worst] Precision_avg[recommended]  \
# 0             0.97175             0.87925                   0.953785
# 1             0.91925              0.8848                   0.866139
# 2             0.95015              0.9046                   0.920075
# 3             0.96365             0.91945                   0.918533
# 4               0.963              0.9447                   0.945098
# 5             0.96305             0.95595                   0.934987
# 6               0.965              0.9348                   0.942993
# 7              0.9357             0.70285                   0.904545
# 8             0.94775              0.8408                   0.915364
# 9             0.97695             0.90715                   0.961333
# 10            0.97095             0.94835                   0.946899
# 11            0.98565              0.9684                   0.975363
# 12            0.98145             0.94915                   0.971063
# 13            0.98375              0.9514                    0.95474
# 14            0.98805              0.9349                   0.967647
# 15             0.9671             0.87485                   0.952866
# 16            0.91975              0.7339                   0.875662
# 17            0.86775              0.7195                   0.821754
# 18            0.89615             0.70515                    0.83972
# 19             0.8974             0.75085                   0.853868
# 20             0.9081              0.8411                   0.868608
# 21            0.92165             0.81435                   0.874974
# 22             0.9631             0.92745                   0.947896
# 23             0.9776             0.89525                    0.96375
# 24            0.88815              0.8114                   0.832959
# 25            0.82165             0.58875                   0.772901
# 26            0.88595              0.8412                    0.82975
# 27            0.92065             0.77275                   0.893989
# 28             0.9607             0.93455                   0.944049
# 29             0.9675              0.9477                   0.941616
# 30             0.9146             0.79815                   0.791662
# 31             0.9356              0.7282                   0.899199
# 32            0.91485              0.8258                   0.810743
# 33             0.9783             0.94805                   0.956406
# 34            0.98215              0.9261                   0.955826
# 35            0.94255              0.8091                   0.907929
# 36             0.9101              0.7447                   0.875736
# 37              0.979              0.8869                    0.95808
# 38             0.9784             0.91895                   0.968089
# 39            0.97125             0.90895                   0.948642
# 40             0.9813             0.97055                   0.971923
# 41             0.9801             0.93615                   0.969426
# 42            0.97825             0.92565                   0.947815
# 43            0.97565             0.88885                   0.963455
# 44             0.9609             0.85705                   0.946488
#
#    Precision_avg[best] Precision_avg[worst] Recall_avg[recommended]  \
# 0             0.953785              0.85842                  0.9827
# 1             0.878482             0.843588                  0.9305
# 2             0.920075             0.872486                  0.9716
# 3             0.945979              0.89732                  0.9789
# 4             0.945098             0.923633                  0.9663
# 5             0.934987             0.937775                  0.9913
# 6             0.942993             0.909471                  0.9795
# 7             0.904545             0.667966                  0.9446
# 8             0.915364             0.816722                  0.9735
# 9             0.961333             0.890751                  0.9875
# 10            0.958614             0.925851                  0.9772
# 11            0.977944             0.952347                  0.9866
# 12            0.971063              0.93106                  0.9847
# 13            0.976103             0.913928                   0.992
# 14            0.979809             0.905675                  0.9916
# 15            0.952866             0.846268                  0.9646
# 16            0.875662             0.701036                  0.9619
# 17            0.817011             0.658157                  0.8637
# 18             0.83972             0.653047                  0.9525
# 19            0.853868             0.690622                  0.9122
# 20            0.859135             0.803023                  0.9039
# 21              0.8965             0.765699                  0.8718
# 22            0.948757             0.901121                  0.9538
# 23            0.970967             0.866322                  0.9743
# 24            0.832959              0.76648                   0.936
# 25            0.772901             0.563398                  0.7882
# 26             0.82975             0.792836                  0.9529
# 27            0.893989             0.741858                  0.9026
# 28            0.944049             0.907327                  0.9578
# 29            0.954061               0.9375                  0.9657
# 30             0.89467             0.791662                    0.61
# 31            0.897821             0.695101                  0.9278
# 32             0.87906             0.810743                  0.6852
# 33            0.966013             0.929503                  0.9632
# 34            0.979045             0.896682                  0.9495
# 35            0.907929             0.772707                  0.9692
# 36            0.880114             0.713047                  0.8943
# 37            0.967914             0.858686                  0.9784
# 38            0.968089             0.901332                  0.9784
# 39            0.958213              0.88324                  0.9207
# 40            0.974671              0.96372                  0.9655
# 41            0.976707             0.921241                  0.9537
# 42            0.970667             0.896233                  0.9823
# 43            0.963455             0.866129                   0.978
# 44            0.942395             0.828032                  0.9497
#
#    Recall_avg[best] Recall_avg[worst] F1_avg[recommended] F1_avg[best]  \
# 0            0.9827             0.808             0.97206      0.97206
# 1            0.9418            0.8753            0.910156     0.921148
# 2            0.9716            0.8927            0.951379     0.951379
# 3            0.9657            0.8919            0.952252     0.963716
# 4            0.9663            0.9363            0.963215     0.963215
# 5            0.9913            0.9518            0.964203     0.964203
# 6            0.9795            0.9278            0.965587     0.965587
# 7            0.9446            0.6881            0.936251     0.936251
# 8            0.9735              0.94            0.949271     0.949271
# 9            0.9875            0.8509            0.977209     0.977209
# 10           0.9681            0.9509            0.966924     0.970859
# 11           0.9874            0.9714            0.984188     0.985685
# 12           0.9847            0.9409            0.981513     0.981513
# 13           0.9834            0.9955            0.974786     0.983729
# 14           0.9933            0.9697            0.981418     0.988126
# 15           0.9646            0.8993            0.967008     0.967008
# 16           0.9619            0.7066            0.923908     0.923908
# 17           0.8801            0.7816            0.867331      0.86927
# 18           0.9525            0.7719            0.901828     0.901828
# 19           0.9122            0.8391            0.898548     0.898548
# 20           0.9475            0.7972            0.904792     0.911645
# 21           0.9023            0.8688            0.894678      0.91931
# 22            0.957            0.9252             0.96125      0.96283
# 23           0.9689            0.8701            0.975079     0.977375
# 24            0.936            0.7526            0.893529     0.893529
# 25           0.7882            0.7854            0.814826     0.814826
# 26           0.9529            0.8203            0.894687     0.894687
# 27           0.9026             0.753            0.919069     0.919069
# 28           0.9578            0.9369            0.960557     0.960557
# 29           0.9642            0.9172            0.961127     0.967414
# 30           0.8743              0.61             0.74675     0.910139
# 31           0.9662            0.6849            0.928717     0.937796
# 32            0.922            0.6852            0.795888     0.915858
# 33           0.9829             0.938            0.968339     0.978432
# 34           0.9706            0.9599             0.96248     0.981931
# 35           0.9692            0.7443            0.944201     0.944201
# 36           0.8919            0.6086            0.906103     0.908171
# 37           0.9813            0.9639            0.973214      0.97905
# 38           0.9784            0.8821            0.978396     0.978396
# 39           0.9703            0.8956            0.952095     0.971219
# 40           0.9763            0.9552            0.976912     0.981136
# 41           0.9671             0.914            0.971268     0.979792
# 42           0.9724            0.9546            0.967171      0.97812
# 43            0.978            0.9128            0.975767     0.975767
# 44           0.9624            0.9097             0.95973     0.960918
#
#    F1_avg[worst]
# 0       0.824166
# 1       0.883662
# 2       0.900057
# 3        0.91518
# 4       0.944177
# 5       0.955717
# 6       0.934305
# 7       0.669603
# 8        0.87413
# 9       0.856313
# 10      0.948735
# 11      0.968499
# 12      0.946836
# 13      0.953729
# 14      0.940333
# 15      0.882756
# 16      0.683072
# 17      0.731731
# 18      0.719914
# 19      0.770146
# 20      0.829249
# 21      0.828165
# 22      0.926834
# 23      0.847831
# 24      0.789134
# 25      0.654599
# 26      0.835946
# 27      0.748492
# 28      0.933786
# 29      0.945549
# 30       0.74675
# 31      0.641894
# 32      0.795888
# 33      0.945807
# 34      0.932368
# 35      0.749923
# 36      0.653758
# 37      0.907294
# 38      0.911719
# 39      0.905728
# 40      0.969897
# 41      0.934866
# 42      0.930716
# 43      0.897996
# 44      0.874623

# %%
rf_results_df.groupby('Recommendation_rank').Task.count()
# Out:
# Recommendation_rank
# 1st    21
# 2nd    14
# 3rd     5
# 4th     3
# 6th     2
# Name: Task, dtype: int64

# %%
oner_results_df
# Out:
#                     Task                              Ranking_architectures  \
# 0    airplane-automobile  MiniVGG3, MiniVGG1, AlexNet1, MiniGoogLeNet1, ...
# 1          airplane-bird  MiniVGG1, MiniGoogLeNet1, MiniVGG3, AlexNet1, ...
# 2           airplane-cat  MiniVGG3, MiniVGG1, AlexNet1, ResNet10, MiniGo...
# 3          airplane-deer  MiniGoogLeNet1, MiniVGG3, AlexNet1, ResNet10, ...
# 4           airplane-dog  MiniVGG3, MiniGoogLeNet1, AlexNet1, MiniVGG1, ...
# ..                   ...                                                ...
# 445            frog-ship  MiniGoogLeNet1, MiniVGG3, MiniVGG1, SmallSquee...
# 446           frog-truck  MiniVGG3, ResNet10, MiniGoogLeNet1, MiniVGG1, ...
# 447           horse-ship  MiniVGG3, AlexNet1, MiniVGG1, MiniGoogLeNet1, ...
# 448          horse-truck  MiniVGG3, MiniVGG1, MiniGoogLeNet1, AlexNet1, ...
# 449           ship-truck  MiniVGG3, MiniGoogLeNet1, AlexNet1, MiniVGG1, ...
#
#     Recommendation_rank P_value[best] P_value[worst]  \
# 0                   2nd      0.484914    0.000121743
# 1                   1st      0.484868    9.13359e-05
# 2                   2nd     0.0808284     0.00405156
# 3                   5th   9.13359e-05      0.0928556
# 4                   4th     0.0032408       0.136157
# ..                  ...           ...            ...
# 445                 3rd     0.0154145       0.171989
# 446                 4th   0.000571086       0.352676
# 447                 3rd    0.00220245      0.0407042
# 448                 2nd    0.00760796      0.0104219
# 449                 4th   0.000373804        0.21298
#
#     Architecture[recommended] Architecture[best] Architecture[worst]  \
# 0                    MiniVGG1           MiniVGG3     SmallSqueezeNet
# 1                    MiniVGG1           MiniVGG1            ResNet10
# 2                    MiniVGG1           MiniVGG3     SmallSqueezeNet
# 3                    MiniVGG1     MiniGoogLeNet1     SmallSqueezeNet
# 4                    MiniVGG1           MiniVGG3            ResNet10
# ..                        ...                ...                 ...
# 445                  MiniVGG1     MiniGoogLeNet1            AlexNet1
# 446                  MiniVGG1           MiniVGG3     SmallSqueezeNet
# 447                  MiniVGG1           MiniVGG3     SmallSqueezeNet
# 448                  MiniVGG1           MiniVGG3     SmallSqueezeNet
# 449                  MiniVGG1           MiniVGG3     SmallSqueezeNet
#
#     Accuracy_avg[recommended] Accuracy_avg[best] Accuracy_avg[worst]  \
# 0                      0.9719            0.97175             0.87925
# 1                     0.91925            0.91925              0.8848
# 2                      0.9439            0.95015              0.9046
# 3                     0.89945            0.96365             0.91945
# 4                      0.9483              0.963              0.9447
# ..                        ...                ...                 ...
# 445                   0.97565             0.9813             0.97055
# 446                   0.96545             0.9801             0.93615
# 447                   0.97085            0.97825             0.92565
# 448                    0.9666            0.97565             0.88885
# 449                   0.94545             0.9609             0.85705
#
#     Precision_avg[recommended] Precision_avg[best] Precision_avg[worst]  \
# 0                     0.956602            0.953785              0.85842
# 1                     0.878482            0.878482             0.843588
# 2                     0.910412            0.920075             0.872486
# 3                     0.836805            0.945979              0.89732
# 4                       0.9141            0.945098             0.923633
# ..                         ...                 ...                  ...
# 445                   0.972557            0.974671              0.96372
# 446                   0.964704            0.976707             0.921241
# 447                    0.95764            0.970667             0.896233
# 448                   0.955483            0.963455             0.866129
# 449                   0.929194            0.942395             0.828032
#
#     Recall_avg[recommended] Recall_avg[best] Recall_avg[worst]  \
# 0                    0.9766           0.9827             0.808
# 1                    0.9418           0.9418            0.8753
# 2                    0.9694           0.9716            0.8927
# 3                    0.9932           0.9657            0.8919
# 4                    0.9797           0.9663            0.9363
# ..                      ...              ...               ...
# 445                  0.9576           0.9763            0.9552
# 446                  0.9324           0.9671             0.914
# 447                  0.9706           0.9724            0.9546
# 448                   0.957            0.978            0.9128
# 449                  0.9263           0.9624            0.9097
#
#     F1_avg[recommended] F1_avg[best] F1_avg[worst]
# 0              0.972037      0.97206      0.824166
# 1              0.921148     0.921148      0.883662
# 2              0.945516     0.951379      0.900057
# 3              0.908942     0.963716       0.91518
# 4              0.950101     0.963215      0.944177
# ..                  ...          ...           ...
# 445            0.975153     0.981136      0.969897
# 446            0.964165     0.979792      0.934866
# 447            0.970888      0.97812      0.930716
# 448            0.966246     0.975767      0.897996
# 449            0.944339     0.960918      0.874623
#
# [450 rows x 20 columns]

# %%
oner_results_df.groupby('Recommendation_rank').Task.count()
# Out:
# Recommendation_rank
# 1st     30
# 2nd     47
# 3rd     60
# 4th    115
# 5th     72
# 6th    126
# Name: Task, dtype: int64

# %%
oner_results_df.groupby('Recommendation_rank').Task.count() / 10
# Out:
# Recommendation_rank
# 1st     3.0
# 2nd     4.7
# 3rd     6.0
# 4th    11.5
# 5th     7.2
# 6th    12.6
# Name: Task, dtype: float64

# %%
random_results_df
# Out:
#                     Task                              Ranking_architectures  \
# 0    airplane-automobile  MiniVGG3, MiniVGG1, AlexNet1, MiniGoogLeNet1, ...
# 1          airplane-bird  MiniVGG1, MiniGoogLeNet1, MiniVGG3, AlexNet1, ...
# 2           airplane-cat  MiniVGG3, MiniVGG1, AlexNet1, ResNet10, MiniGo...
# 3          airplane-deer  MiniGoogLeNet1, MiniVGG3, AlexNet1, ResNet10, ...
# 4           airplane-dog  MiniVGG3, MiniGoogLeNet1, AlexNet1, MiniVGG1, ...
# ..                   ...                                                ...
# 445            frog-ship  MiniGoogLeNet1, MiniVGG3, MiniVGG1, SmallSquee...
# 446           frog-truck  MiniVGG3, ResNet10, MiniGoogLeNet1, MiniVGG1, ...
# 447           horse-ship  MiniVGG3, AlexNet1, MiniVGG1, MiniGoogLeNet1, ...
# 448          horse-truck  MiniVGG3, MiniVGG1, MiniGoogLeNet1, AlexNet1, ...
# 449           ship-truck  MiniVGG3, MiniGoogLeNet1, AlexNet1, MiniVGG1, ...
#
#     Recommendation_rank P_value[best] P_value[worst]  \
# 0                   5th   9.08256e-05       0.484919
# 1                   2nd      0.410132    9.08256e-05
# 2                   4th    0.00109688       0.236338
# 3                   5th   9.13359e-05      0.0928556
# 4                   6th   0.000641022       0.484681
# ..                  ...           ...            ...
# 445                 6th    0.00138271       0.484822
# 446                 6th   0.000842869       0.484868
# 447                 2nd      0.153472     0.00289768
# 448                 6th   0.000740226       0.484868
# 449                 2nd      0.424942    0.000217639
#
#     Architecture[recommended] Architecture[best] Architecture[worst]  \
# 0                    ResNet10           MiniVGG3     SmallSqueezeNet
# 1              MiniGoogLeNet1           MiniVGG1            ResNet10
# 2                    ResNet10           MiniVGG3     SmallSqueezeNet
# 3                    MiniVGG1     MiniGoogLeNet1     SmallSqueezeNet
# 4                    ResNet10           MiniVGG3            ResNet10
# ..                        ...                ...                 ...
# 445                  AlexNet1     MiniGoogLeNet1            AlexNet1
# 446           SmallSqueezeNet           MiniVGG3     SmallSqueezeNet
# 447                  AlexNet1           MiniVGG3     SmallSqueezeNet
# 448           SmallSqueezeNet           MiniVGG3     SmallSqueezeNet
# 449            MiniGoogLeNet1           MiniVGG3     SmallSqueezeNet
#
#     Accuracy_avg[recommended] Accuracy_avg[best] Accuracy_avg[worst]  \
# 0                     0.92505            0.97175             0.87925
# 1                      0.9186            0.91925              0.8848
# 2                      0.9258            0.95015              0.9046
# 3                     0.89945            0.96365             0.91945
# 4                      0.9447              0.963              0.9447
# ..                        ...                ...                 ...
# 445                   0.97055             0.9813             0.97055
# 446                   0.93615             0.9801             0.93615
# 447                   0.97515            0.97825             0.92565
# 448                   0.88885            0.97565             0.88885
# 449                    0.9602             0.9609             0.85705
#
#     Precision_avg[recommended] Precision_avg[best] Precision_avg[worst]  \
# 0                     0.892683            0.953785              0.85842
# 1                     0.885863            0.878482             0.843588
# 2                     0.893557            0.920075             0.872486
# 3                     0.836805            0.945979              0.89732
# 4                     0.923633            0.945098             0.923633
# ..                         ...                 ...                  ...
# 445                    0.96372            0.974671              0.96372
# 446                   0.921241            0.976707             0.921241
# 447                   0.965768            0.970667             0.896233
# 448                   0.866129            0.963455             0.866129
# 449                   0.946488            0.942395             0.828032
#
#     Recall_avg[recommended] Recall_avg[best] Recall_avg[worst]  \
# 0                    0.9274           0.9827             0.808
# 1                    0.9158           0.9418            0.8753
# 2                    0.9279           0.9716            0.8927
# 3                    0.9932           0.9657            0.8919
# 4                    0.9363           0.9663            0.9363
# ..                      ...              ...               ...
# 445                  0.9552           0.9763            0.9552
# 446                   0.914           0.9671             0.914
# 447                  0.9703           0.9724            0.9546
# 448                  0.9128            0.978            0.9128
# 449                  0.9497           0.9624            0.9097
#
#     F1_avg[recommended] F1_avg[best] F1_avg[worst]
# 0              0.925149      0.97206      0.824166
# 1              0.918248     0.921148      0.883662
# 2              0.925876     0.951379      0.900057
# 3              0.908942     0.963716       0.91518
# 4              0.944177     0.963215      0.944177
# ..                  ...          ...           ...
# 445            0.969897     0.981136      0.969897
# 446            0.934866     0.979792      0.934866
# 447            0.975042      0.97812      0.930716
# 448            0.897996     0.975767      0.897996
# 449             0.95973     0.960918      0.874623
#
# [450 rows x 20 columns]

# %%
random_results_df.groupby('Recommendation_rank').Task.count()
# Out:
# Recommendation_rank
# 1st    79
# 2nd    81
# 3rd    78
# 4th    71
# 5th    78
# 6th    63
# Name: Task, dtype: int64

# %%
random_results_df.groupby('Recommendation_rank').Task.count() / 10
# Out:
# Recommendation_rank
# 1st    7.9
# 2nd    8.1
# 3rd    7.8
# 4th    7.1
# 5th    7.8
# 6th    6.3
# Name: Task, dtype: float64

# %%
algorithms_recommendations_dfs = {
    'RF': rf_results_df,
    'KNN': knn_results_df,
    'SVM': svm_results_df,
    'OneR': oner_results_df,
    'Random': random_results_df
}

# %%
metrics_dfs = {}
for algorithm, recommendations_df in algorithms_recommendations_dfs.items():
    metrics_dfs[algorithm] = recommendations_df.groupby('Task').apply(np.mean).reset_index()

# %%
data = {}
for algorithm, metrics_df in metrics_dfs.items():
    data[algorithm] = {
        'Accuracy_mean': np.mean(metrics_df['Accuracy_avg[recommended]']),
        'Accuracy_std': np.std(metrics_df['Accuracy_avg[recommended]']),
        'Precision_mean': np.mean(metrics_df['Precision_avg[recommended]']),
        'Precision_std': np.std(metrics_df['Precision_avg[recommended]']),
        'Recall_mean': np.mean(metrics_df['Recall_avg[recommended]']),
        'Recall_std': np.std(metrics_df['Recall_avg[recommended]']),
        'F1_mean': np.mean(metrics_df['F1_avg[recommended]']),
        'F1_std': np.std(metrics_df['F1_avg[recommended]'])
    }
pd.DataFrame(data).T
# Out:
#         Accuracy_mean  Accuracy_std  Precision_mean  Precision_std  \
# RF           0.938761      0.044964        0.914763       0.054290
# KNN          0.941274      0.037270        0.916748       0.050772
# SVM          0.943724      0.037266        0.919432       0.050595
# OneR         0.905430      0.060347        0.874970       0.072991
# Random       0.922422      0.050555        0.895310       0.062567
#
#         Recall_mean  Recall_std   F1_mean    F1_std
# RF         0.937918    0.074419  0.937237  0.050824
# KNN        0.945071    0.042019  0.941309  0.037305
# SVM        0.949509    0.041889  0.944140  0.037148
# OneR       0.912719    0.062319  0.903363  0.061730
# Random     0.923879    0.050347  0.921332  0.051275

# %%
data = {}
for algorithm, recommendations_df in algorithms_recommendations_dfs.items():
    data[algorithm] = recommendations_df.groupby(
        'Recommendation_rank'
    ).Task.count().divide(10 if algorithm in {'Random', 'OneR'} else 1)
pd.DataFrame(data).fillna(0)
# Out:
#        RF   KNN   SVM  OneR  Random
# 1st  21.0  14.0  23.0   3.0     7.9
# 2nd  14.0  19.0  16.0   4.7     8.1
# 3rd   5.0   6.0   6.0   6.0     7.8
# 4th   3.0   6.0   0.0  11.5     7.1
# 5th   0.0   0.0   0.0   7.2     7.8
# 6th   2.0   0.0   0.0  12.6     6.3

# %%
data = {}
for algorithm, recommendations_df in algorithms_recommendations_dfs.items():
    data[algorithm] = recommendations_df.groupby(
        'Recommendation_rank'
    ).Task.count().divide(len(recommendations_df))
pd.DataFrame(data).fillna(0)
# Out:
#            RF       KNN       SVM      OneR    Random
# 1st  0.466667  0.311111  0.511111  0.066667  0.175556
# 2nd  0.311111  0.422222  0.355556  0.104444  0.180000
# 3rd  0.111111  0.133333  0.133333  0.133333  0.173333
# 4th  0.066667  0.133333  0.000000  0.255556  0.157778
# 5th  0.000000  0.000000  0.000000  0.160000  0.173333
# 6th  0.044444  0.000000  0.000000  0.280000  0.140000

# %%
data = {}
for algorithm, metrics_df in metrics_dfs.items():
    data[algorithm] = {
        'Accuracy_p_value': mannwhitneyu(
            metrics_df['Accuracy_avg[recommended]'],
            metrics_df['Accuracy_avg[best]']
        )[1],
        'Precision_p_value': mannwhitneyu(
            metrics_df['Precision_avg[recommended]'],
            metrics_df['Precision_avg[best]']
        )[1],
        'Recall_p_value': mannwhitneyu(
            metrics_df['Recall_avg[recommended]'],
            metrics_df['Recall_avg[best]']
        )[1],
        'F1_p_value': mannwhitneyu(
            metrics_df['F1_avg[recommended]'],
            metrics_df['F1_avg[best]']
        )[1]
    }
pd.DataFrame(data)
# Out:
#                          RF       KNN       SVM      OneR    Random
# Accuracy_p_value   0.139750  0.120154  0.219236  0.000038  0.001083
# Precision_p_value  0.165405  0.178787  0.284689  0.000132  0.003966
# Recall_p_value     0.260564  0.116952  0.318418  0.000018  0.000068
# F1_p_value         0.131837  0.099719  0.218049  0.000037  0.000606

# %%
def make_cd_diagram(metric):
    algorithms = list(metrics_dfs.keys())
    data = [
        metrics_dfs[algorithm][metric].tolist()
        for algorithm in algorithms
    ]
    data.append(metrics_dfs[algorithm][metric.replace('recommended', 'best')])
    algorithms.append('GT')
    result_df = posthoc_nemenyi(data)
    result_df.index, result_df.columns = algorithms, algorithms
    names = algorithms
    avranks = (1 - np.abs(result_df['GT'])) * 5 + 1
    cd = Orange.evaluation.compute_CD(avranks, 45)
    print('cd:', cd)
    Orange.evaluation.graph_ranks(avranks, names, cd=cd)
    plt.savefig(f'{metric}.png', dpi=1200, bbox_inches='tight')
    plt.show()

# %%
make_cd_diagram('Accuracy_avg[recommended]')
# Out:
# cd: 1.1239388092198597

# %%
make_cd_diagram('Precision_avg[recommended]')
# Out:
# cd: 1.1239388092198597

# %%
make_cd_diagram('Recall_avg[recommended]')
# Out:
# cd: 1.1239388092198597

# %%
make_cd_diagram('F1_avg[recommended]')
# Out:
# cd: 1.1239388092198597

# %%
data = {
    'Algorithm': [],
    'Accuracy': [],
    'Recall': [],
    'Precision': [],
    'F-Score': []
}

for algorithm, metrics_df in metrics_dfs.items():
    data['Algorithm'].append(algorithm)
    data['Recall'].append(np.mean(metrics_df['Recall_avg[recommended]']))
    data['Accuracy'].append(np.mean(metrics_df['Accuracy_avg[recommended]']))
    data['F-Score'].append(np.mean(metrics_df['F1_avg[recommended]']))
    data['Precision'].append(np.mean(metrics_df['Precision_avg[recommended]']))

df = pd.DataFrame(data)

# ------- PART 1: Create background

# number of variable
categories = list(df)[1:]
N = len(categories)

# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * math.pi for n in range(N)]
angles += angles[:1]

# Initialise the spider plot
ax = plt.subplot(111, polar=True)

# If you want the first axis to be on top:
ax.set_theta_offset(math.pi / 2)
ax.set_theta_direction(-1)

# Draw one axe per variable + add labels labels yet
plt.xticks(angles[:-1], categories)

# Draw ylabels
ax.set_rlabel_position(45)
plt.yticks([0.87, 0.9, 0.93, 0.96], ["0.87", "0.90", "0.93", "0.96"], color="black", size=7)
plt.ylim(0.87, 0.96)

# ------- PART 2: Add plots

# Plot each individual = each line of the data
# I don't do a loop, because plotting more than 3 groups makes the chart unreadable

# Ind1
algorithm = df.loc[0]['Algorithm']
values = df.loc[0].drop('Algorithm').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label=algorithm, color='red', marker='.')
#ax.fill(angles, values, 'b', alpha=0.1)

# Ind2
algorithm = df.loc[1]['Algorithm']
values = df.loc[1].drop('Algorithm').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label=algorithm, color='blue', marker='x')
#ax.fill(angles, values, 'r', alpha=0.1)

# Ind3
algorithm = df.loc[2]['Algorithm']
values = df.loc[2].drop('Algorithm').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label=algorithm, color='black', marker='^')
#ax.fill(angles, values, 'r', alpha=0.1)

# Ind4
algorithm = df.loc[3]['Algorithm']
values = df.loc[3].drop('Algorithm').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label=algorithm, color='green', marker='+')
#ax.fill(angles, values, 'r', alpha=0.1)

# Ind5
algorithm = df.loc[4]['Algorithm']
values = df.loc[4].drop('Algorithm').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label=algorithm, color='orange', marker='*')
#ax.fill(angles, values, 'b', alpha=0.1)

# Add legend
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))

plt.savefig('radar.png', dpi=1200, bbox_inches='tight')
plt.show()
