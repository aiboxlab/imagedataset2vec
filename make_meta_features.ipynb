# %%
import os
import re
import pickle
import numpy as np
import pandas as pd

from pathlib import Path
from sklearn.preprocessing import normalize
from sklearn.cluster import KMeans

# %%
PATH_DATA = Path('data')
PATH_RAW_FEATURES = PATH_DATA / 'raw_features'
PATH_META_FEATURES = PATH_DATA / 'meta_features'

# %%
def make_task_meta_features(task_features: np.ndarray) -> np.ndarray:
    task_features_normalized = normalize(task_features, axis=0)
    kmeans = KMeans(n_clusters=2, n_jobs=3)
    kmeans.fit(task_features_normalized)
    centroids = kmeans.cluster_centers_
    return np.add(*centroids) / centroids.shape[0]

# %%
with open(PATH_DATA / 'tasks_indexes.pkl', 'rb') as f:
    tasks_indexes = pickle.load(f)

# %%
# %%time

for filename in os.listdir(PATH_RAW_FEATURES):
    feature_extractor = re.search(r'^.*(?=\.csv$)', filename).group()
    raw_features_df = pd.read_csv(PATH_RAW_FEATURES / filename)
    os.makedirs(PATH_META_FEATURES / feature_extractor, exist_ok=True)
    for task, index in tasks_indexes.items():
        print('Making meta features for:', f'{feature_extractor}[{task}]...')
        task_raw_features = raw_features_df.values[index]
        task_meta_features = make_task_meta_features(task_raw_features)
        with open(PATH_META_FEATURES / feature_extractor / f'{task}.pkl', 'wb') as f:
            pickle.dump(task_meta_features, f)
# Out:
# Making meta features for: mnasnet[airplane-automobile]...
# Making meta features for: mnasnet[airplane-bird]...
# Making meta features for: mnasnet[airplane-cat]...
# Making meta features for: mnasnet[airplane-deer]...
# Making meta features for: mnasnet[airplane-dog]...
# Making meta features for: mnasnet[airplane-frog]...
# Making meta features for: mnasnet[airplane-horse]...
# Making meta features for: mnasnet[airplane-ship]...
# Making meta features for: mnasnet[airplane-truck]...
# Making meta features for: mnasnet[automobile-bird]...
# Making meta features for: mnasnet[automobile-cat]...
# Making meta features for: mnasnet[automobile-deer]...
# Making meta features for: mnasnet[automobile-dog]...
# Making meta features for: mnasnet[automobile-frog]...
# Making meta features for: mnasnet[automobile-horse]...
# Making meta features for: mnasnet[automobile-ship]...
# Making meta features for: mnasnet[automobile-truck]...
# Making meta features for: mnasnet[bird-cat]...
# Making meta features for: mnasnet[bird-deer]...
# Making meta features for: mnasnet[bird-dog]...
# Making meta features for: mnasnet[bird-frog]...
# Making meta features for: mnasnet[bird-horse]...
# Making meta features for: mnasnet[bird-ship]...
# Making meta features for: mnasnet[bird-truck]...
# Making meta features for: mnasnet[cat-deer]...
# Making meta features for: mnasnet[cat-dog]...
# Making meta features for: mnasnet[cat-frog]...
# Making meta features for: mnasnet[cat-horse]...
# Making meta features for: mnasnet[cat-ship]...
# Making meta features for: mnasnet[cat-truck]...
# Making meta features for: mnasnet[deer-dog]...
# Making meta features for: mnasnet[deer-frog]...
# Making meta features for: mnasnet[deer-horse]...
# Making meta features for: mnasnet[deer-ship]...
# Making meta features for: mnasnet[deer-truck]...
# Making meta features for: mnasnet[dog-frog]...
# Making meta features for: mnasnet[dog-horse]...
# Making meta features for: mnasnet[dog-ship]...
# Making meta features for: mnasnet[dog-truck]...
# Making meta features for: mnasnet[frog-horse]...
# Making meta features for: mnasnet[frog-ship]...
# Making meta features for: mnasnet[frog-truck]...
# Making meta features for: mnasnet[horse-ship]...
# Making meta features for: mnasnet[horse-truck]...
# Making meta features for: mnasnet[ship-truck]...
# Making meta features for: wrn[airplane-automobile]...
# Making meta features for: wrn[airplane-bird]...
# Making meta features for: wrn[airplane-cat]...
# Making meta features for: wrn[airplane-deer]...
# Making meta features for: wrn[airplane-dog]...
# Making meta features for: wrn[airplane-frog]...
# Making meta features for: wrn[airplane-horse]...
# Making meta features for: wrn[airplane-ship]...
# Making meta features for: wrn[airplane-truck]...
# Making meta features for: wrn[automobile-bird]...
# Making meta features for: wrn[automobile-cat]...
# Making meta features for: wrn[automobile-deer]...
# Making meta features for: wrn[automobile-dog]...
# Making meta features for: wrn[automobile-frog]...
# Making meta features for: wrn[automobile-horse]...
# Making meta features for: wrn[automobile-ship]...
# Making meta features for: wrn[automobile-truck]...
# Making meta features for: wrn[bird-cat]...
# Making meta features for: wrn[bird-deer]...
# Making meta features for: wrn[bird-dog]...
# Making meta features for: wrn[bird-frog]...
# Making meta features for: wrn[bird-horse]...
# Making meta features for: wrn[bird-ship]...
# Making meta features for: wrn[bird-truck]...
# Making meta features for: wrn[cat-deer]...
# Making meta features for: wrn[cat-dog]...
# Making meta features for: wrn[cat-frog]...
# Making meta features for: wrn[cat-horse]...
# Making meta features for: wrn[cat-ship]...
# Making meta features for: wrn[cat-truck]...
# Making meta features for: wrn[deer-dog]...
# Making meta features for: wrn[deer-frog]...
# Making meta features for: wrn[deer-horse]...
# Making meta features for: wrn[deer-ship]...
# Making meta features for: wrn[deer-truck]...
# Making meta features for: wrn[dog-frog]...
# Making meta features for: wrn[dog-horse]...
# Making meta features for: wrn[dog-ship]...
# Making meta features for: wrn[dog-truck]...
# Making meta features for: wrn[frog-horse]...
# Making meta features for: wrn[frog-ship]...
# Making meta features for: wrn[frog-truck]...
# Making meta features for: wrn[horse-ship]...
# Making meta features for: wrn[horse-truck]...
# Making meta features for: wrn[ship-truck]...
# Making meta features for: resnext[airplane-automobile]...
# Making meta features for: resnext[airplane-bird]...
# Making meta features for: resnext[airplane-cat]...
# Making meta features for: resnext[airplane-deer]...
# Making meta features for: resnext[airplane-dog]...
# Making meta features for: resnext[airplane-frog]...
# Making meta features for: resnext[airplane-horse]...
# Making meta features for: resnext[airplane-ship]...
# Making meta features for: resnext[airplane-truck]...
# Making meta features for: resnext[automobile-bird]...
# Making meta features for: resnext[automobile-cat]...
# Making meta features for: resnext[automobile-deer]...
# Making meta features for: resnext[automobile-dog]...
# Making meta features for: resnext[automobile-frog]...
# Making meta features for: resnext[automobile-horse]...
# Making meta features for: resnext[automobile-ship]...
# Making meta features for: resnext[automobile-truck]...
# Making meta features for: resnext[bird-cat]...
# Making meta features for: resnext[bird-deer]...
# Making meta features for: resnext[bird-dog]...
# Making meta features for: resnext[bird-frog]...
# Making meta features for: resnext[bird-horse]...
# Making meta features for: resnext[bird-ship]...
# Making meta features for: resnext[bird-truck]...
# Making meta features for: resnext[cat-deer]...
# Making meta features for: resnext[cat-dog]...
# Making meta features for: resnext[cat-frog]...
# Making meta features for: resnext[cat-horse]...
# Making meta features for: resnext[cat-ship]...
# Making meta features for: resnext[cat-truck]...
# Making meta features for: resnext[deer-dog]...
# Making meta features for: resnext[deer-frog]...
# Making meta features for: resnext[deer-horse]...
# Making meta features for: resnext[deer-ship]...
# Making meta features for: resnext[deer-truck]...
# Making meta features for: resnext[dog-frog]...
# Making meta features for: resnext[dog-horse]...
# Making meta features for: resnext[dog-ship]...
# Making meta features for: resnext[dog-truck]...
# Making meta features for: resnext[frog-horse]...
# Making meta features for: resnext[frog-ship]...
# Making meta features for: resnext[frog-truck]...
# Making meta features for: resnext[horse-ship]...
# Making meta features for: resnext[horse-truck]...
# Making meta features for: resnext[ship-truck]...
# Making meta features for: densenet[airplane-automobile]...
# Making meta features for: densenet[airplane-bird]...
# Making meta features for: densenet[airplane-cat]...
# Making meta features for: densenet[airplane-deer]...
# Making meta features for: densenet[airplane-dog]...
# Making meta features for: densenet[airplane-frog]...
# Making meta features for: densenet[airplane-horse]...
# Making meta features for: densenet[airplane-ship]...
# Making meta features for: densenet[airplane-truck]...
# Making meta features for: densenet[automobile-bird]...
# Making meta features for: densenet[automobile-cat]...
# Making meta features for: densenet[automobile-deer]...
# Making meta features for: densenet[automobile-dog]...
# Making meta features for: densenet[automobile-frog]...
# Making meta features for: densenet[automobile-horse]...
# Making meta features for: densenet[automobile-ship]...
# Making meta features for: densenet[automobile-truck]...
# Making meta features for: densenet[bird-cat]...
# Making meta features for: densenet[bird-deer]...
# Making meta features for: densenet[bird-dog]...
# Making meta features for: densenet[bird-frog]...
# Making meta features for: densenet[bird-horse]...
# Making meta features for: densenet[bird-ship]...
# Making meta features for: densenet[bird-truck]...
# Making meta features for: densenet[cat-deer]...
# Making meta features for: densenet[cat-dog]...
# Making meta features for: densenet[cat-frog]...
# Making meta features for: densenet[cat-horse]...
# Making meta features for: densenet[cat-ship]...
# Making meta features for: densenet[cat-truck]...
# Making meta features for: densenet[deer-dog]...
# Making meta features for: densenet[deer-frog]...
# Making meta features for: densenet[deer-horse]...
# Making meta features for: densenet[deer-ship]...
# Making meta features for: densenet[deer-truck]...
# Making meta features for: densenet[dog-frog]...
# Making meta features for: densenet[dog-horse]...
# Making meta features for: densenet[dog-ship]...
# Making meta features for: densenet[dog-truck]...
# Making meta features for: densenet[frog-horse]...
# Making meta features for: densenet[frog-ship]...
# Making meta features for: densenet[frog-truck]...
# Making meta features for: densenet[horse-ship]...
# Making meta features for: densenet[horse-truck]...
# Making meta features for: densenet[ship-truck]...
# Making meta features for: shufflenet[airplane-automobile]...
# Making meta features for: shufflenet[airplane-bird]...
# Making meta features for: shufflenet[airplane-cat]...
# Making meta features for: shufflenet[airplane-deer]...
# Making meta features for: shufflenet[airplane-dog]...
# Making meta features for: shufflenet[airplane-frog]...
# Making meta features for: shufflenet[airplane-horse]...
# Making meta features for: shufflenet[airplane-ship]...
# Making meta features for: shufflenet[airplane-truck]...
# Making meta features for: shufflenet[automobile-bird]...
# Making meta features for: shufflenet[automobile-cat]...
# Making meta features for: shufflenet[automobile-deer]...
# Making meta features for: shufflenet[automobile-dog]...
# Making meta features for: shufflenet[automobile-frog]...
# Making meta features for: shufflenet[automobile-horse]...
# Making meta features for: shufflenet[automobile-ship]...
# Making meta features for: shufflenet[automobile-truck]...
# Making meta features for: shufflenet[bird-cat]...
# Making meta features for: shufflenet[bird-deer]...
# Making meta features for: shufflenet[bird-dog]...
# Making meta features for: shufflenet[bird-frog]...
# Making meta features for: shufflenet[bird-horse]...
# Making meta features for: shufflenet[bird-ship]...
# Making meta features for: shufflenet[bird-truck]...
# Making meta features for: shufflenet[cat-deer]...
# Making meta features for: shufflenet[cat-dog]...
# Making meta features for: shufflenet[cat-frog]...
# Making meta features for: shufflenet[cat-horse]...
# Making meta features for: shufflenet[cat-ship]...
# Making meta features for: shufflenet[cat-truck]...
# Making meta features for: shufflenet[deer-dog]...
# Making meta features for: shufflenet[deer-frog]...
# Making meta features for: shufflenet[deer-horse]...
# Making meta features for: shufflenet[deer-ship]...
# Making meta features for: shufflenet[deer-truck]...
# Making meta features for: shufflenet[dog-frog]...
# Making meta features for: shufflenet[dog-horse]...
# Making meta features for: shufflenet[dog-ship]...
# Making meta features for: shufflenet[dog-truck]...
# Making meta features for: shufflenet[frog-horse]...
# Making meta features for: shufflenet[frog-ship]...
# Making meta features for: shufflenet[frog-truck]...
# Making meta features for: shufflenet[horse-ship]...
# Making meta features for: shufflenet[horse-truck]...
# Making meta features for: shufflenet[ship-truck]...
# Making meta features for: handcraft[airplane-automobile]...
# Making meta features for: handcraft[airplane-bird]...
# Making meta features for: handcraft[airplane-cat]...
# Making meta features for: handcraft[airplane-deer]...
# Making meta features for: handcraft[airplane-dog]...
# Making meta features for: handcraft[airplane-frog]...
# Making meta features for: handcraft[airplane-horse]...
# Making meta features for: handcraft[airplane-ship]...
# Making meta features for: handcraft[airplane-truck]...
# Making meta features for: handcraft[automobile-bird]...
# Making meta features for: handcraft[automobile-cat]...
# Making meta features for: handcraft[automobile-deer]...
# Making meta features for: handcraft[automobile-dog]...
# Making meta features for: handcraft[automobile-frog]...
# Making meta features for: handcraft[automobile-horse]...
# Making meta features for: handcraft[automobile-ship]...
# Making meta features for: handcraft[automobile-truck]...
# Making meta features for: handcraft[bird-cat]...
# Making meta features for: handcraft[bird-deer]...
# Making meta features for: handcraft[bird-dog]...
# Making meta features for: handcraft[bird-frog]...
# Making meta features for: handcraft[bird-horse]...
# Making meta features for: handcraft[bird-ship]...
# Making meta features for: handcraft[bird-truck]...
# Making meta features for: handcraft[cat-deer]...
# Making meta features for: handcraft[cat-dog]...
# Making meta features for: handcraft[cat-frog]...
# Making meta features for: handcraft[cat-horse]...
# Making meta features for: handcraft[cat-ship]...
# Making meta features for: handcraft[cat-truck]...
# Making meta features for: handcraft[deer-dog]...
# Making meta features for: handcraft[deer-frog]...
# Making meta features for: handcraft[deer-horse]...
# Making meta features for: handcraft[deer-ship]...
# Making meta features for: handcraft[deer-truck]...
# Making meta features for: handcraft[dog-frog]...
# Making meta features for: handcraft[dog-horse]...
# Making meta features for: handcraft[dog-ship]...
# Making meta features for: handcraft[dog-truck]...
# Making meta features for: handcraft[frog-horse]...
# Making meta features for: handcraft[frog-ship]...
# Making meta features for: handcraft[frog-truck]...
# Making meta features for: handcraft[horse-ship]...
# Making meta features for: handcraft[horse-truck]...
# Making meta features for: handcraft[ship-truck]...
# Making meta features for: squeezenet[airplane-automobile]...
# Making meta features for: squeezenet[airplane-bird]...
# Making meta features for: squeezenet[airplane-cat]...
# Making meta features for: squeezenet[airplane-deer]...
# Making meta features for: squeezenet[airplane-dog]...
# Making meta features for: squeezenet[airplane-frog]...
# Making meta features for: squeezenet[airplane-horse]...
# Making meta features for: squeezenet[airplane-ship]...
# Making meta features for: squeezenet[airplane-truck]...
# Making meta features for: squeezenet[automobile-bird]...
# Making meta features for: squeezenet[automobile-cat]...
# Making meta features for: squeezenet[automobile-deer]...
# Making meta features for: squeezenet[automobile-dog]...
# Making meta features for: squeezenet[automobile-frog]...
# Making meta features for: squeezenet[automobile-horse]...
# Making meta features for: squeezenet[automobile-ship]...
# Making meta features for: squeezenet[automobile-truck]...
# Making meta features for: squeezenet[bird-cat]...
# Making meta features for: squeezenet[bird-deer]...
# Making meta features for: squeezenet[bird-dog]...
# Making meta features for: squeezenet[bird-frog]...
# Making meta features for: squeezenet[bird-horse]...
# Making meta features for: squeezenet[bird-ship]...
# Making meta features for: squeezenet[bird-truck]...
# Making meta features for: squeezenet[cat-deer]...
# Making meta features for: squeezenet[cat-dog]...
# Making meta features for: squeezenet[cat-frog]...
# Making meta features for: squeezenet[cat-horse]...
# Making meta features for: squeezenet[cat-ship]...
# Making meta features for: squeezenet[cat-truck]...
# Making meta features for: squeezenet[deer-dog]...
# Making meta features for: squeezenet[deer-frog]...
# Making meta features for: squeezenet[deer-horse]...
# Making meta features for: squeezenet[deer-ship]...
# Making meta features for: squeezenet[deer-truck]...
# Making meta features for: squeezenet[dog-frog]...
# Making meta features for: squeezenet[dog-horse]...
# Making meta features for: squeezenet[dog-ship]...
# Making meta features for: squeezenet[dog-truck]...
# Making meta features for: squeezenet[frog-horse]...
# Making meta features for: squeezenet[frog-ship]...
# Making meta features for: squeezenet[frog-truck]...
# Making meta features for: squeezenet[horse-ship]...
# Making meta features for: squeezenet[horse-truck]...
# Making meta features for: squeezenet[ship-truck]...
# Making meta features for: resnet[airplane-automobile]...
# Making meta features for: resnet[airplane-bird]...
# Making meta features for: resnet[airplane-cat]...
# Making meta features for: resnet[airplane-deer]...
# Making meta features for: resnet[airplane-dog]...
# Making meta features for: resnet[airplane-frog]...
# Making meta features for: resnet[airplane-horse]...
# Making meta features for: resnet[airplane-ship]...
# Making meta features for: resnet[airplane-truck]...
# Making meta features for: resnet[automobile-bird]...
# Making meta features for: resnet[automobile-cat]...
# Making meta features for: resnet[automobile-deer]...
# Making meta features for: resnet[automobile-dog]...
# Making meta features for: resnet[automobile-frog]...
# Making meta features for: resnet[automobile-horse]...
# Making meta features for: resnet[automobile-ship]...
# Making meta features for: resnet[automobile-truck]...
# Making meta features for: resnet[bird-cat]...
# Making meta features for: resnet[bird-deer]...
# Making meta features for: resnet[bird-dog]...
# Making meta features for: resnet[bird-frog]...
# Making meta features for: resnet[bird-horse]...
# Making meta features for: resnet[bird-ship]...
# Making meta features for: resnet[bird-truck]...
# Making meta features for: resnet[cat-deer]...
# Making meta features for: resnet[cat-dog]...
# Making meta features for: resnet[cat-frog]...
# Making meta features for: resnet[cat-horse]...
# Making meta features for: resnet[cat-ship]...
# Making meta features for: resnet[cat-truck]...
# Making meta features for: resnet[deer-dog]...
# Making meta features for: resnet[deer-frog]...
# Making meta features for: resnet[deer-horse]...
# Making meta features for: resnet[deer-ship]...
# Making meta features for: resnet[deer-truck]...
# Making meta features for: resnet[dog-frog]...
# Making meta features for: resnet[dog-horse]...
# Making meta features for: resnet[dog-ship]...
# Making meta features for: resnet[dog-truck]...
# Making meta features for: resnet[frog-horse]...
# Making meta features for: resnet[frog-ship]...
# Making meta features for: resnet[frog-truck]...
# Making meta features for: resnet[horse-ship]...
# Making meta features for: resnet[horse-truck]...
# Making meta features for: resnet[ship-truck]...
# Making meta features for: mobilenet[airplane-automobile]...
# Making meta features for: mobilenet[airplane-bird]...
# Making meta features for: mobilenet[airplane-cat]...
# Making meta features for: mobilenet[airplane-deer]...
# Making meta features for: mobilenet[airplane-dog]...
# Making meta features for: mobilenet[airplane-frog]...
# Making meta features for: mobilenet[airplane-horse]...
# Making meta features for: mobilenet[airplane-ship]...
# Making meta features for: mobilenet[airplane-truck]...
# Making meta features for: mobilenet[automobile-bird]...
# Making meta features for: mobilenet[automobile-cat]...
# Making meta features for: mobilenet[automobile-deer]...
# Making meta features for: mobilenet[automobile-dog]...
# Making meta features for: mobilenet[automobile-frog]...
# Making meta features for: mobilenet[automobile-horse]...
# Making meta features for: mobilenet[automobile-ship]...
# Making meta features for: mobilenet[automobile-truck]...
# Making meta features for: mobilenet[bird-cat]...
# Making meta features for: mobilenet[bird-deer]...
# Making meta features for: mobilenet[bird-dog]...
# Making meta features for: mobilenet[bird-frog]...
# Making meta features for: mobilenet[bird-horse]...
# Making meta features for: mobilenet[bird-ship]...
# Making meta features for: mobilenet[bird-truck]...
# Making meta features for: mobilenet[cat-deer]...
# Making meta features for: mobilenet[cat-dog]...
# Making meta features for: mobilenet[cat-frog]...
# Making meta features for: mobilenet[cat-horse]...
# Making meta features for: mobilenet[cat-ship]...
# Making meta features for: mobilenet[cat-truck]...
# Making meta features for: mobilenet[deer-dog]...
# Making meta features for: mobilenet[deer-frog]...
# Making meta features for: mobilenet[deer-horse]...
# Making meta features for: mobilenet[deer-ship]...
# Making meta features for: mobilenet[deer-truck]...
# Making meta features for: mobilenet[dog-frog]...
# Making meta features for: mobilenet[dog-horse]...
# Making meta features for: mobilenet[dog-ship]...
# Making meta features for: mobilenet[dog-truck]...
# Making meta features for: mobilenet[frog-horse]...
# Making meta features for: mobilenet[frog-ship]...
# Making meta features for: mobilenet[frog-truck]...
# Making meta features for: mobilenet[horse-ship]...
# Making meta features for: mobilenet[horse-truck]...
# Making meta features for: mobilenet[ship-truck]...
# CPU times: user 5min 25s, sys: 57.1 s, total: 6min 22s
# Wall time: 43min 5s
